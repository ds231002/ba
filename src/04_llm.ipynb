# %% [markdown]
# ## Methode 2

# %%
from utils.create_system_prompts import create_system_prompt_for_method
from utils.llm import generate_response

# %%
system_prompt = create_system_prompt_for_method(2)
user_prompt = "Wie war mein Verbrauch letzte Woche?"

response = generate_response(user_prompt, system_prompt, "qwen3:8b")

# %%
print(response["finish_reason"])
print(response["model"])
print(response["usage"])
print(response["answer"])
# Out:
# stop
# qwen3:8b
# {'runtime_seconds': 18.00962719999916, 'input_tokens': 4778, 'output_tokens': 1271, 'total_tokens': 6049}
# {
#   "plan": [
#     {
#       "id": "step_1",
#       "tool": "get_measured_energy",
#       "arguments": {
#         "metering_point_id": "mp_1",
#         "start": "2025-12-26 00:00:00",
#         "end": "2025-12-31 23:59:59"
#       }
#     },
#     {
#       "id": "step_2",
#       "tool": "get_measured_energy",
#       "arguments": {
#         "metering_point_id": "mp_2",
#         "start": "2025-12-26 00:00:00",
#         "end": "2025-12-31 23:59:59"
#       }
#     },
#     {
#       "id": "step_3",
#       "tool": "add_timeseries",
#       "arguments": {
#         "timeseries": [
#           {
#             "$ref": "step_1"
#           },
#           {
#             "$ref": "step_2"
#           }
#         ]
#       }
#     },
#     {
#       "id": "step_4",
#       "tool": "generate_answer",
#       "arguments": {
# ...
