# %% [markdown]
# # Tools

# %%
from typing import List, Optional

# %% [markdown]
# ## Datenabfrage

# %% [markdown]
# ### Extern

# %%
def get_astronomical_sun_hours(start, end):
    # bool per h
    pass

def get_spot_market(start, end):
    # awattar.at/tariffs/hourly
    pass

def get_k_next_knowledge(phrase: str, catrgories: list[str], k):
    # keine echte Funktion - nur Parameterauswahl bewerten
    # feste Kategorieauswahl definieren
    pass

def search_knowledge_for(word: str):
    pass

# %% [markdown]
# ### Energy Community

# %%
# only whole energy community
# Verbrauch, Erzeugung gesamt?

def get_community_coverage(start, end):
    pass

def get_community_potential(start, end):
    pass

def get_predicted_consumption(date):
    # per h
    # how concat on plot? - auto concat, no separat function?
    pass

def get_predicted_generation(date):
    # like consumption
    pass

# %%
# optional

def get_surplus_generation(cp, start, end): # delete?
    pass

def get_current_power_consumption(cp):
    pass # kW

def get_current_power_generation(cp):
    pass # kW

# %% [markdown]
# ### Teilnahmefaktor

# %%
def get_participation_factor(cp, date):
    # täglich
    pass

# %% [markdown]
# ### Measured

# %%
# from cp, location, all?

def get_measured_consumption(cp, start, end):
    pass

def get_measured_generation(cp, start, end):
    pass

# %% [markdown]
# ### Weighted

# %%
def get_weighted_measured_consumption(start, end):
    pass

def get_weighted_measured_generation(start, end):
    pass

def get_weighted_surplus_generation(start, end):
    # from cp, from location, all?
    # delete?
    pass

# %% [markdown]
# ## Plot

# %%
# Weitere Grafiken?
# immer für chat?

def create_energy_plot(energy_data: list, show_in_chat: bool):
    # Vergleichsgrafiken (Verbrauch, Erzeugung, Überschuss) auf einmal?
    pass

def create_spotmarket_plot(spot_market):
    pass

def create_sun_hours_plot(sun_hours):
    pass

# %% [markdown]
# ## Analyze

# %%
def get_statistical_value(statistic_type: str, time_series: List[float]) -> Optional[float]:
    allowed_statistics = ["max", "min", "avg", "sum"]

    if statistic_type not in allowed_statistics:
        raise ValueError(f"Ungültiger Statistiktyp. Erlaubt sind: {allowed_statistics}")

    pass

def get_energy_pattern(energy_data):
    # generation, consumption
    # sample result
    pass


def time_series_analysis(energy_data: list, prompt):
    # vl-time
    # Qwen2.5-VL/Llama 3.2 Vision/Gemma 3 (Vision)/MiniCPM-V
    pass

def analyze_plot(plot, prompt):
    # Zusammengeführter Plot (mehrere Linien) in Plots generieren?
    pass

def calculate_spotmarket_energy_consumption(energy_data, spotmarket):
    # spotmarket Preisberechnung, Ersparnis?
    pass

# %% [markdown]
# ## Finalize

# %%
def generate_answer():
    pass
