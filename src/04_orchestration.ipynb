# %%
# import pandas as pd
from datetime import datetime
from utils.files import read_csv
from utils.orchestration import (
    generate_result_for_task_with_method_1,
    generate_result_for_task_with_method_2,
    generate_result_for_task_with_method_3,
    save_result_as_json
)

# %% [markdown]
# ## LLM Test

# %%
from utils.llm import generate_response
from utils.create_system_prompts import create_system_prompt_for_method_1

task_id = "1"
task_type = "warmup"
# task = "Wann hat meine Energiegemeinschaft letzten Monat am meisten verbraucht?"
task = "Wie hoch ist mein Verbrauch gerade und was ist mein Teilnamefaktor?"
system_prompt = create_system_prompt_for_method_1()
model = "qwen3:30b"

response = generate_response(task, system_prompt, model)

# %% [markdown]
# ## Method 1

# %%
task_id = "1"
task_type = "warmup"
# task = "Wann hat meine Energiegemeinschaft letzten Monat am meisten verbraucht?"
task = "Generiere mir eine Grafik vom Verbrauch meiner Energiegemeinschaft letzten Monat."
method = "deterministic"
model = "qwen3:30b"

result = generate_result_for_task_with_method_1(task_id, task_type, task, model)
result_path = save_result_as_json(result, task_id, task_type, method, model)
print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] [SAVED] {result_path}")
# Out:
# [2026-08-31 08:42:07] [SAVED] output\results\warmup\1\deterministic_qwen3_30b.json

# %% [markdown]
# ## Method 2

# %%
task_id = "1"
task_type = "warmup"
# task = "Gib mir den Gesamtverbrauch aller meiner Zählpunkte letzte Woche."
task = "Generiere mir eine Grafik vom Verbrauch meiner Energiegemeinschaft letzten Monat."
method = "plan-based"
model = "qwen3:30b"

result = generate_result_for_task_with_method_2(task_id, task_type, task, model)
result_path = save_result_as_json(result, task_id, task_type, method, model)
print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] [SAVED] {result_path}")
# Out:
# [2026-08-31 08:42:39] [SAVED] output\results\warmup\1\plan-based_qwen3_30b.json

# %% [markdown]
# ## Method 3

# %%
task_id = "1"
task_type = "warmup"
task = "Generiere mir eine Grafik vom Verbrauch meiner Energiegemeinschaft letzten Monat."
method = "iterative"
model = "qwen3:30b"

result = generate_result_for_task_with_method_3(task_id, task_type, task, model)
result_path = save_result_as_json(result, task_id, task_type, method, model)
print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] [SAVED] {result_path}")
# Out:
# [2026-08-31 10:07:16] [SAVED] output\results\warmup\1\iterative_qwen3_30b.json

# %% [markdown]
# ## Method 1, 2, 3

# %%
tasks = read_csv("tasks.csv")
# tasks = tasks[tasks["ID"] >= 21]
model = "qwen3:8b"

for _, row in tasks.iterrows():
    task_id = row["ID"]
    task_type = row["Aufgabentyp"]
    task = row["Aufgabe"]

    method = "deterministic"
    result = generate_result_for_task_with_method_1(task_id, task_type, task, model)
    result_path = save_result_as_json(result, task_id, task_type, method, model)
    print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] [SAVED] {result_path}")

    method = "plan-based"
    result = generate_result_for_task_with_method_2(task_id, task_type, task, model)
    result_path = save_result_as_json(result, task_id, task_type, method, model)
    print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] [SAVED] {result_path}")

    method = "iterative"
    result = generate_result_for_task_with_method_3(task_id, task_type, task, model)
    result_path = save_result_as_json(result, task_id, task_type, method, model)
    print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] [SAVED] {result_path}")
# Out:
# [2026-08-31 00:06:00] [SAVED] output\results\Direkte Datenabfrage\1\deterministic_qwen3_8b.json
# [2026-08-31 00:06:12] [SAVED] output\results\Direkte Datenabfrage\1\plan-based_qwen3_8b.json
# [2026-08-31 00:06:20] [SAVED] output\results\Direkte Datenabfrage\1\iterative_qwen3_8b.json
# [2026-08-31 00:06:31] [SAVED] output\results\Direkte Datenabfrage\2\deterministic_qwen3_8b.json
# [2026-08-31 00:06:39] [SAVED] output\results\Direkte Datenabfrage\2\plan-based_qwen3_8b.json
# [2026-08-31 00:06:48] [SAVED] output\results\Direkte Datenabfrage\2\iterative_qwen3_8b.json
# [2026-08-31 00:06:52] [SAVED] output\results\Direkte Datenabfrage\3\deterministic_qwen3_8b.json
# [2026-08-31 00:06:56] [SAVED] output\results\Direkte Datenabfrage\3\plan-based_qwen3_8b.json
# [2026-08-31 00:07:03] [SAVED] output\results\Direkte Datenabfrage\3\iterative_qwen3_8b.json
# [2026-08-31 00:07:07] [SAVED] output\results\Direkte Datenabfrage\4\deterministic_qwen3_8b.json
# [2026-08-31 00:07:09] [SAVED] output\results\Direkte Datenabfrage\4\plan-based_qwen3_8b.json
# [2026-08-31 00:07:16] [SAVED] output\results\Direkte Datenabfrage\4\iterative_qwen3_8b.json
# [2026-08-31 00:07:19] [SAVED] output\results\Direkte Datenabfrage\5\deterministic_qwen3_8b.json
# [2026-08-31 00:07:22] [SAVED] output\results\Direkte Datenabfrage\5\plan-based_qwen3_8b.json
# [2026-08-31 00:07:28] [SAVED] output\results\Direkte Datenabfrage\5\iterative_qwen3_8b.json
# [2026-08-31 00:07:31] [SAVED] output\results\Direkte Datenabfrage\6\deterministic_qwen3_8b.json
# [2026-08-31 00:07:35] [SAVED] output\results\Direkte Datenabfrage\6\plan-based_qwen3_8b.json
# [2026-08-31 00:07:44] [SAVED] output\results\Direkte Datenabfrage\6\iterative_qwen3_8b.json
# [2026-08-31 00:08:01] [SAVED] output\results\Direkte Datenabfrage\7\deterministic_qwen3_8b.json
# [2026-08-31 00:08:07] [SAVED] output\results\Direkte Datenabfrage\7\plan-based_qwen3_8b.json
# [2026-08-31 00:08:13] [SAVED] output\results\Direkte Datenabfrage\7\iterative_qwen3_8b.json
# [2026-08-31 00:08:15] [SAVED] output\results\Direkte Datenabfrage\8\deterministic_qwen3_8b.json
# [2026-08-31 00:08:18] [SAVED] output\results\Direkte Datenabfrage\8\plan-based_qwen3_8b.json
# [2026-08-31 00:08:23] [SAVED] output\results\Direkte Datenabfrage\8\iterative_qwen3_8b.json
# [2026-08-31 00:08:51] [SAVED] output\results\Direkte Datenabfrage\9\deterministic_qwen3_8b.json
# [2026-08-31 00:08:58] [SAVED] output\results\Direkte Datenabfrage\9\plan-based_qwen3_8b.json
# [2026-08-31 00:09:25] [SAVED] output\results\Direkte Datenabfrage\9\iterative_qwen3_8b.json
# [2026-08-31 00:09:29] [SAVED] output\results\Direkte Datenabfrage\10\deterministic_qwen3_8b.json
# [2026-08-31 00:09:35] [SAVED] output\results\Direkte Datenabfrage\10\plan-based_qwen3_8b.json
# [2026-08-31 00:09:46] [SAVED] output\results\Direkte Datenabfrage\10\iterative_qwen3_8b.json
# [2026-08-31 00:10:01] [SAVED] output\results\Direkte Datenabfrage\11\deterministic_qwen3_8b.json
# [2026-08-31 00:10:16] [SAVED] output\results\Direkte Datenabfrage\11\plan-based_qwen3_8b.json
# [2026-08-31 00:10:26] [SAVED] output\results\Direkte Datenabfrage\11\iterative_qwen3_8b.json
# [2026-08-31 00:10:30] [SAVED] output\results\Direkte Datenabfrage\12\deterministic_qwen3_8b.json
# [2026-08-31 00:10:34] [SAVED] output\results\Direkte Datenabfrage\12\plan-based_qwen3_8b.json
# [2026-08-31 00:10:42] [SAVED] output\results\Direkte Datenabfrage\12\iterative_qwen3_8b.json
# [2026-08-31 00:10:46] [SAVED] output\results\Direkte Datenabfrage\13\deterministic_qwen3_8b.json
# [2026-08-31 00:10:54] [SAVED] output\results\Direkte Datenabfrage\13\plan-based_qwen3_8b.json
# [2026-08-31 00:11:29] [SAVED] output\results\Direkte Datenabfrage\13\iterative_qwen3_8b.json
# [2026-08-31 00:11:33] [SAVED] output\results\Direkte Datenabfrage\14\deterministic_qwen3_8b.json
# [2026-08-31 00:11:37] [SAVED] output\results\Direkte Datenabfrage\14\plan-based_qwen3_8b.json
# [2026-08-31 00:11:45] [SAVED] output\results\Direkte Datenabfrage\14\iterative_qwen3_8b.json
# [2026-08-31 00:11:49] [SAVED] output\results\Direkte Datenabfrage\15\deterministic_qwen3_8b.json
# [2026-08-31 00:11:54] [SAVED] output\results\Direkte Datenabfrage\15\plan-based_qwen3_8b.json
# [2026-08-31 00:12:04] [SAVED] output\results\Direkte Datenabfrage\15\iterative_qwen3_8b.json
# [2026-08-31 00:12:09] [SAVED] output\results\Direkte Datenabfrage\16\deterministic_qwen3_8b.json
# [2026-08-31 00:12:20] [SAVED] output\results\Direkte Datenabfrage\16\plan-based_qwen3_8b.json
# [2026-08-31 00:12:30] [SAVED] output\results\Direkte Datenabfrage\16\iterative_qwen3_8b.json
# [2026-08-31 00:12:33] [SAVED] output\results\Direkte Datenabfrage\17\deterministic_qwen3_8b.json
# [2026-08-31 00:12:48] [SAVED] output\results\Direkte Datenabfrage\17\plan-based_qwen3_8b.json
# [2026-08-31 00:13:03] [SAVED] output\results\Direkte Datenabfrage\17\iterative_qwen3_8b.json
# [2026-08-31 00:13:07] [SAVED] output\results\Direkte Datenabfrage\18\deterministic_qwen3_8b.json
# [2026-08-31 00:13:18] [SAVED] output\results\Direkte Datenabfrage\18\plan-based_qwen3_8b.json
# [2026-08-31 00:13:29] [SAVED] output\results\Direkte Datenabfrage\18\iterative_qwen3_8b.json
# [2026-08-31 00:13:36] [SAVED] output\results\Direkte Datenabfrage\19\deterministic_qwen3_8b.json
# [2026-08-31 00:13:41] [SAVED] output\results\Direkte Datenabfrage\19\plan-based_qwen3_8b.json
# [2026-08-31 00:17:29] [SAVED] output\results\Direkte Datenabfrage\19\iterative_qwen3_8b.json
# [2026-08-31 00:17:39] [SAVED] output\results\Direkte Datenabfrage\20\deterministic_qwen3_8b.json
# [2026-08-31 00:17:54] [SAVED] output\results\Direkte Datenabfrage\20\plan-based_qwen3_8b.json
# [2026-08-31 00:18:04] [SAVED] output\results\Direkte Datenabfrage\20\iterative_qwen3_8b.json

# %%
tasks = read_csv("tasks.csv")
# tasks = tasks[tasks["ID"] >= 21]
model = "qwen3:30b"

for _, row in tasks.iterrows():
    task_id = row["ID"]
    task_type = row["Aufgabentyp"]
    task = row["Aufgabe"]

    method = "deterministic"
    result = generate_result_for_task_with_method_1(task_id, task_type, task, model)
    result_path = save_result_as_json(result, task_id, task_type, method, model)
    print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] [SAVED] {result_path}")

    method = "plan-based"
    result = generate_result_for_task_with_method_2(task_id, task_type, task, model)
    result_path = save_result_as_json(result, task_id, task_type, method, model)
    print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] [SAVED] {result_path}")

    method = "iterative"
    result = generate_result_for_task_with_method_3(task_id, task_type, task, model)
    result_path = save_result_as_json(result, task_id, task_type, method, model)
    print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] [SAVED] {result_path}")
