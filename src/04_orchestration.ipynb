# %%
from utils.orchestration import (
    generate_result_for_task_with_method_1,
    generate_result_for_task_with_method_2,
    generate_result_for_task_with_method_3,
    save_result_as_json
)

# %% [markdown]
# ## Methode 1

# %%
task_id = "1"
task_type = "single_step"
task = "Gib mir den Gesamtverbrauch aller meiner Zählpunkte letzte Woche."
method = "plan-based"
model = "qwen3:4b"

result = generate_result_for_task_with_method_1(task_id, task_type, task, model)
result_path = save_result_as_json(result, task_id, task_type, method, model)
print(f"[SAVED] {result_path}")
# Out:
# result saved: output\results\einfach\1\plan-based_qwen3_4b.json

# %% [markdown]
# ## Methode 2

# %%
task_id = "1"
task_type = "single-step"
task = "Gib mir den Gesamtverbrauch aller meiner Zählpunkte letzte Woche."
method = "plan-based"
model = "qwen3:4b"

result = generate_result_for_task_with_method_2(task_id, task_type, task, model)
result_path = save_result_as_json(result, task_id, task_type, method, model)
print(f"[SAVED] {result_path}")
# Out:
# [SAVED] output\results\einfach\1\plan-based_qwen3_4b.json

# %% [markdown]
# ## Methode 3

# %%
task_id = "1"
task_type = "single-step"
task = "Gib mir den Gesamtverbrauch aller meiner Zählpunkte letzte Woche."
model = "qwen3:4b"

result = generate_result_for_task_with_method_3(task_id, task_type, task, model)
result_path = save_result_as_json(result, task_id, task_type, method, model)
print(f"[SAVED] {result_path}")
# Out:
# ===== Iteration 1 =====
# available_results = []
# START generate_response ....
# END generate_response
# iteration = {'tool_calls': [{'id': 'i1_r1', 'tool': 'get_measured_energy', 'arguments': {'metering_point_id': 'mp_1', 'start': '2025-12-26 00:00:00', 'end': '2026-01-01 00:00:00'}}, {'id': 'i1_r2', 'tool': 'get_measured_energy', 'arguments': {'metering_point_id': 'mp_2', 'start': '2025-12-26 00:00:00', 'end': '2026-01-01 00:00:00'}}], 'usage': {'runtime_seconds': 27.11628290000226, 'input_tokens': 5447, 'output_tokens': 1952, 'total_tokens': 7399}, 'finish_reason': 'stop'}
# ===== Iteration 2 =====
# available_results = [{'rsult_id': 'i1_r1', 'tool': 'get_measured_energy', 'arguments': {'metering_point_id': 'mp_1', 'start': '2025-12-26 00:00:00', 'end': '2026-01-01 00:00:00'}, 'result': {'type': 'timeseries', 'preview': [{'timestamp': Timestamp('2025-12-26 00:00:00'), 'kwh': 0.103}, {'timestamp': Timestamp('2025-12-26 00:15:00'), 'kwh': 0.128}, {'timestamp': Timestamp('2025-12-26 00:30:00'), 'kwh': 0.259}]}}, {'rsult_id': 'i1_r2', 'tool': 'get_measured_energy', 'arguments': {'metering_point_id': 'mp_2', 'start': '2025-12-26 00:00:00', 'end': '2026-01-01 00:00:00'}, 'result': {'type': 'timeseries', 'preview': [{'timestamp': Timestamp('2025-12-26 00:00:00'), 'kwh': 0.239}, {'timestamp': Timestamp('2025-12-26 00:15:00'), 'kwh': 0.137}, {'timestamp': Timestamp('2025-12-26 00:30:00'), 'kwh': 0.207}]}}]
# START generate_response ....
# END generate_response
# iteration = {'tool_calls': [{'id': 'i2_r1', 'tool': 'add_timeseries', 'arguments': {'timeseries': ['i1_r1', 'i1_r2']}}], 'usage': {'runtime_seconds': 14.947626400000445, 'input_tokens': 5928, 'output_tokens': 1965, 'total_tokens': 7893}, 'finish_reason': 'stop'}
# ===== Iteration 3 =====
# available_results = [{'rsult_id': 'i1_r1', 'tool': 'get_measured_energy', 'arguments': {'metering_point_id': 'mp_1', 'start': '2025-12-26 00:00:00', 'end': '2026-01-01 00:00:00'}, 'result': {'type': 'timeseries', 'preview': [{'timestamp': Timestamp('2025-12-26 00:00:00'), 'kwh': 0.103}, {'timestamp': Timestamp('2025-12-26 00:15:00'), 'kwh': 0.128}, {'timestamp': Timestamp('2025-12-26 00:30:00'), 'kwh': 0.259}]}}, {'rsult_id': 'i1_r2', 'tool': 'get_measured_energy', 'arguments': {'metering_point_id': 'mp_2', 'start': '2025-12-26 00:00:00', 'end': '2026-01-01 00:00:00'}, 'result': {'type': 'timeseries', 'preview': [{'timestamp': Timestamp('2025-12-26 00:00:00'), 'kwh': 0.239}, {'timestamp': Timestamp('2025-12-26 00:15:00'), 'kwh': 0.137}, {'timestamp': Timestamp('2025-12-26 00:30:00'), 'kwh': 0.207}]}}, {'tool': 'add_timeseries', 'arguments': {'timeseries': ['i1_r1', 'i1_r2']}, 'error': "'str' object has no attribute 'copy'"}]
# START generate_response ....
# END generate_response
# iteration = {'tool_calls': [{'id': 'i3_r1', 'tool': 'add_timeseries', 'arguments': {'timeseries': ['i1_r1', 'i1_r2']}}], 'usage': {'runtime_seconds': 23.502415399998426, 'input_tokens': 5984, 'output_tokens': 3149, 'total_tokens': 9133}, 'finish_reason': 'stop'}
# ===== Iteration 4 =====
# available_results = [{'rsult_id': 'i1_r1', 'tool': 'get_measured_energy', 'arguments': {'metering_point_id': 'mp_1', 'start': '2025-12-26 00:00:00', 'end': '2026-01-01 00:00:00'}, 'result': {'type': 'timeseries', 'preview': [{'timestamp': Timestamp('2025-12-26 00:00:00'), 'kwh': 0.103}, {'timestamp': Timestamp('2025-12-26 00:15:00'), 'kwh': 0.128}, {'timestamp': Timestamp('2025-12-26 00:30:00'), 'kwh': 0.259}]}}, {'rsult_id': 'i1_r2', 'tool': 'get_measured_energy', 'arguments': {'metering_point_id': 'mp_2', 'start': '2025-12-26 00:00:00', 'end': '2026-01-01 00:00:00'}, 'result': {'type': 'timeseries', 'preview': [{'timestamp': Timestamp('2025-12-26 00:00:00'), 'kwh': 0.239}, {'timestamp': Timestamp('2025-12-26 00:15:00'), 'kwh': 0.137}, {'timestamp': Timestamp('2025-12-26 00:30:00'), 'kwh': 0.207}]}}, {'tool': 'add_timeseries', 'arguments': {'timeseries': ['i1_r1', 'i1_r2']}, 'error': "'str' object has no attribute 'copy'"}, {'tool': 'add_timeseries', 'arguments': {'timeseries': ['i1_r1', 'i1_r2']}, 'error': "'str' object has no attribute 'copy'"}]
# START generate_response ....
# END generate_response
# iteration = {'tool_calls': [{'id': 'i4_r1', 'tool': 'add_timeseries', 'arguments': {'timeseries': ['i1_r1', 'i1_r2']}}], 'usage': {'runtime_seconds': 14.474751699999615, 'input_tokens': 6040, 'output_tokens': 1937, 'total_tokens': 7977}, 'finish_reason': 'stop'}
# ===== Iteration 5 =====
# available_results = [{'rsult_id': 'i1_r1', 'tool': 'get_measured_energy', 'arguments': {'metering_point_id': 'mp_1', 'start': '2025-12-26 00:00:00', 'end': '2026-01-01 00:00:00'}, 'result': {'type': 'timeseries', 'preview': [{'timestamp': Timestamp('2025-12-26 00:00:00'), 'kwh': 0.103}, {'timestamp': Timestamp('2025-12-26 00:15:00'), 'kwh': 0.128}, {'timestamp': Timestamp('2025-12-26 00:30:00'), 'kwh': 0.259}]}}, {'rsult_id': 'i1_r2', 'tool': 'get_measured_energy', 'arguments': {'metering_point_id': 'mp_2', 'start': '2025-12-26 00:00:00', 'end': '2026-01-01 00:00:00'}, 'result': {'type': 'timeseries', 'preview': [{'timestamp': Timestamp('2025-12-26 00:00:00'), 'kwh': 0.239}, {'timestamp': Timestamp('2025-12-26 00:15:00'), 'kwh': 0.137}, {'timestamp': Timestamp('2025-12-26 00:30:00'), 'kwh': 0.207}]}}, {'tool': 'add_timeseries', 'arguments': {'timeseries': ['i1_r1', 'i1_r2']}, 'error': "'str' object has no attribute 'copy'"}, {'tool': 'add_timeseries', 'arguments': {'timeseries': ['i1_r1', 'i1_r2']}, 'error': "'str' object has no attribute 'copy'"}, {'tool': 'add_timeseries', 'arguments': {'timeseries': ['i1_r1', 'i1_r2']}, 'error': "'str' object has no attribute 'copy'"}]
# START generate_response ....
# END generate_response
# iteration = {'tool_calls': [{'id': 'i5_r1', 'tool': 'add_timeseries', 'arguments': {'timeseries': ['i1_r1', 'i1_r2']}}], 'usage': {'runtime_seconds': 28.738699199999246, 'input_tokens': 6096, 'output_tokens': 3823, 'total_tokens': 9919}, 'finish_reason': 'stop'}
# ===== Iteration 6 =====
# available_results = [{'rsult_id': 'i1_r1', 'tool': 'get_measured_energy', 'arguments': {'metering_point_id': 'mp_1', 'start': '2025-12-26 00:00:00', 'end': '2026-01-01 00:00:00'}, 'result': {'type': 'timeseries', 'preview': [{'timestamp': Timestamp('2025-12-26 00:00:00'), 'kwh': 0.103}, {'timestamp': Timestamp('2025-12-26 00:15:00'), 'kwh': 0.128}, {'timestamp': Timestamp('2025-12-26 00:30:00'), 'kwh': 0.259}]}}, {'rsult_id': 'i1_r2', 'tool': 'get_measured_energy', 'arguments': {'metering_point_id': 'mp_2', 'start': '2025-12-26 00:00:00', 'end': '2026-01-01 00:00:00'}, 'result': {'type': 'timeseries', 'preview': [{'timestamp': Timestamp('2025-12-26 00:00:00'), 'kwh': 0.239}, {'timestamp': Timestamp('2025-12-26 00:15:00'), 'kwh': 0.137}, {'timestamp': Timestamp('2025-12-26 00:30:00'), 'kwh': 0.207}]}}, {'tool': 'add_timeseries', 'arguments': {'timeseries': ['i1_r1', 'i1_r2']}, 'error': "'str' object has no attribute 'copy'"}, {'tool': 'add_timeseries', 'arguments': {'timeseries': ['i1_r1', 'i1_r2']}, 'error': "'str' object has no attribute 'copy'"}, {'tool': 'add_timeseries', 'arguments': {'timeseries': ['i1_r1', 'i1_r2']}, 'error': "'str' object has no attribute 'copy'"}, {'tool': 'add_timeseries', 'arguments': {'timeseries': ['i1_r1', 'i1_r2']}, 'error': "'str' object has no attribute 'copy'"}]
# START generate_response ....
# END generate_response
# iteration = {'tool_calls': [{'id': 'i6_r1', 'tool': 'add_timeseries', 'arguments': {'timeseries': ['i1_r1', 'i1_r2']}}], 'usage': {'runtime_seconds': 23.10708919999888, 'input_tokens': 6152, 'output_tokens': 3039, 'total_tokens': 9191}, 'finish_reason': 'stop'}
# result saved: output\results\einfach\1\iterative_qwen3_30b.json
