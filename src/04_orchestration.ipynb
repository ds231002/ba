# %%
# import pandas as pd
from datetime import datetime
from utils.files import read_csv
from utils.orchestration import (
    generate_result_for_task_with_method_1,
    generate_result_for_task_with_method_2,
    generate_result_for_task_with_method_3,
    save_result_as_json
)

# %% [markdown]
# ## LLM Test

# %%
# from utils.llm import generate_response
# from utils.create_system_prompts import create_system_prompt_for_method_1

# task_id = "1"
# task_type = "warmup"
# # task = "Wann hat meine Energiegemeinschaft letzten Monat am meisten verbraucht?"
# task = "Wie hoch ist mein Verbrauch gerade und was ist mein Teilnamefaktor?"
# system_prompt = create_system_prompt_for_method_1()
# model = "qwen3:30b"

# response = generate_response(task, system_prompt, model)

# %% [markdown]
# ## Method 1

# %%
task_id = "1"
task_type = "warmup"
# task = "Wann hat meine Energiegemeinschaft letzten Monat am meisten verbraucht?"
task = "Generiere mir eine Grafik vom Verbrauch meiner Energiegemeinschaft letzten Monat."
method = "deterministic"
model = "gpt-5.4-mini-2026-03-17"

result = generate_result_for_task_with_method_1(task_id, task_type, task, model)
result_path = save_result_as_json(result, task_id, task_type, method, model)
print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] [SAVED] {result_path}")
# Out:
# [2026-08-31 23:49:29] [SAVED] output\results\warmup\1\deterministic_gpt-5.4-mini-2026-03-17.json

# %% [markdown]
# ## Method 2

# %%
task_id = "2"
task_type = "warmup"
# task = "Gib mir den Gesamtverbrauch aller meiner Zählpunkte letzte Woche."
task = "Generiere mir eine Grafik vom Verbrauch meiner Energiegemeinschaft letzten Monat."
method = "plan-based"
model = "gpt-5.4-mini-2026-03-17"

result = generate_result_for_task_with_method_2(task_id, task_type, task, model)
result_path = save_result_as_json(result, task_id, task_type, method, model)
print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] [SAVED] {result_path}")
# Out:
# [2026-08-31 23:49:00] [SAVED] output\results\warmup\2\plan-based_gpt-5.4-mini-2026-03-17.json

# %% [markdown]
# ## Method 3

# %%
task_id = "1"
task_type = "warmup"
# task = "Generiere mir eine Grafik vom Verbrauch meiner Energiegemeinschaft letzten Monat."
task = "Zeige mir meinen Verbrauch über das letzte Monat abzüglich meiner Erzeugung."
method = "iterative"
model = "gpt-5.4-mini-2026-03-17"

result = generate_result_for_task_with_method_3(task_id, task_type, task, model)
result_path = save_result_as_json(result, task_id, task_type, method, model)
print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] [SAVED] {result_path}")
# Out:
# [2026-08-31 23:47:19] [SAVED] output\results\warmup\1\iterative_gpt-5.4-mini-2026-03-17.json

# %% [markdown]
# ## Method 1, 2, 3

# %%
# tasks = read_csv("tasks/tasks.csv")
# model = "qwen3:4b"

# for _, row in tasks.iterrows():
#     task_id = row["ID"]
#     task_type = row["Aufgabentyp"]
#     task = row["Aufgabe"]

#     method = "deterministic"
#     result = generate_result_for_task_with_method_1(task_id, task_type, task, model)
#     result_path = save_result_as_json(result, task_id, task_type, method, model)
#     print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] [SAVED] {result_path}")

#     method = "plan-based"
#     result = generate_result_for_task_with_method_2(task_id, task_type, task, model)
#     result_path = save_result_as_json(result, task_id, task_type, method, model)
#     print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] [SAVED] {result_path}")

#     method = "iterative"
#     result = generate_result_for_task_with_method_3(task_id, task_type, task, model)
#     result_path = save_result_as_json(result, task_id, task_type, method, model)
#     print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] [SAVED] {result_path}")

# %%
tasks = read_csv("tasks/tasks.csv")
model = "qwen3:8b"

for _, row in tasks.iterrows():
    task_id = row["ID"]
    task_type = row["Aufgabentyp"]
    task = row["Aufgabe"]

    method = "deterministic"
    result = generate_result_for_task_with_method_1(task_id, task_type, task, model)
    result_path = save_result_as_json(result, task_id, task_type, method, model)
    print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] [SAVED] {result_path}")

    method = "plan-based"
    result = generate_result_for_task_with_method_2(task_id, task_type, task, model)
    result_path = save_result_as_json(result, task_id, task_type, method, model)
    print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] [SAVED] {result_path}")

    method = "iterative"
    result = generate_result_for_task_with_method_3(task_id, task_type, task, model)
    result_path = save_result_as_json(result, task_id, task_type, method, model)
    print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] [SAVED] {result_path}")
# Out:
# [2026-08-31 10:24:12] [SAVED] output\results\Direkte Datenabfrage\1\deterministic_qwen3_8b.json
# [2026-08-31 10:24:27] [SAVED] output\results\Direkte Datenabfrage\1\plan-based_qwen3_8b.json
# [2026-08-31 10:24:40] [SAVED] output\results\Direkte Datenabfrage\1\iterative_qwen3_8b.json
# [2026-08-31 10:24:51] [SAVED] output\results\Direkte Datenabfrage\2\deterministic_qwen3_8b.json
# [2026-08-31 10:25:03] [SAVED] output\results\Direkte Datenabfrage\2\plan-based_qwen3_8b.json
# [2026-08-31 10:25:10] [SAVED] output\results\Direkte Datenabfrage\2\iterative_qwen3_8b.json
# [2026-08-31 10:25:17] [SAVED] output\results\Direkte Datenabfrage\3\deterministic_qwen3_8b.json
# [2026-08-31 10:25:24] [SAVED] output\results\Direkte Datenabfrage\3\plan-based_qwen3_8b.json
# [2026-08-31 10:25:36] [SAVED] output\results\Direkte Datenabfrage\3\iterative_qwen3_8b.json
# [2026-08-31 10:25:48] [SAVED] output\results\Direkte Datenabfrage\4\deterministic_qwen3_8b.json
# [2026-08-31 10:25:54] [SAVED] output\results\Direkte Datenabfrage\4\plan-based_qwen3_8b.json
# [2026-08-31 10:26:05] [SAVED] output\results\Direkte Datenabfrage\4\iterative_qwen3_8b.json
# [2026-08-31 10:26:13] [SAVED] output\results\Direkte Datenabfrage\5\deterministic_qwen3_8b.json
# [2026-08-31 10:26:18] [SAVED] output\results\Direkte Datenabfrage\5\plan-based_qwen3_8b.json
# [2026-08-31 10:26:29] [SAVED] output\results\Direkte Datenabfrage\5\iterative_qwen3_8b.json
# [2026-08-31 10:26:35] [SAVED] output\results\Direkte Datenabfrage\6\deterministic_qwen3_8b.json
# [2026-08-31 10:26:41] [SAVED] output\results\Direkte Datenabfrage\6\plan-based_qwen3_8b.json
# [2026-08-31 10:26:53] [SAVED] output\results\Direkte Datenabfrage\6\iterative_qwen3_8b.json
# [2026-08-31 10:27:09] [SAVED] output\results\Direkte Datenabfrage\7\deterministic_qwen3_8b.json
# [2026-08-31 10:27:18] [SAVED] output\results\Direkte Datenabfrage\7\plan-based_qwen3_8b.json
# [2026-08-31 10:27:28] [SAVED] output\results\Direkte Datenabfrage\7\iterative_qwen3_8b.json
# [2026-08-31 10:27:34] [SAVED] output\results\Direkte Datenabfrage\8\deterministic_qwen3_8b.json
# [2026-08-31 10:27:40] [SAVED] output\results\Direkte Datenabfrage\8\plan-based_qwen3_8b.json
# [2026-08-31 10:27:50] [SAVED] output\results\Direkte Datenabfrage\8\iterative_qwen3_8b.json
# [2026-08-31 10:27:58] [SAVED] output\results\Direkte Datenabfrage\9\deterministic_qwen3_8b.json
# [2026-08-31 10:28:07] [SAVED] output\results\Direkte Datenabfrage\9\plan-based_qwen3_8b.json
# [2026-08-31 10:28:36] [SAVED] output\results\Direkte Datenabfrage\9\iterative_qwen3_8b.json
# [2026-08-31 10:28:44] [SAVED] output\results\Direkte Datenabfrage\10\deterministic_qwen3_8b.json
# [2026-08-31 10:28:53] [SAVED] output\results\Direkte Datenabfrage\10\plan-based_qwen3_8b.json
# [2026-08-31 10:29:08] [SAVED] output\results\Direkte Datenabfrage\10\iterative_qwen3_8b.json
# [2026-08-31 10:29:20] [SAVED] output\results\Direkte Datenabfrage\11\deterministic_qwen3_8b.json
# [2026-08-31 10:29:37] [SAVED] output\results\Direkte Datenabfrage\11\plan-based_qwen3_8b.json
# [2026-08-31 10:29:53] [SAVED] output\results\Direkte Datenabfrage\11\iterative_qwen3_8b.json
# [2026-08-31 10:30:08] [SAVED] output\results\Direkte Datenabfrage\12\deterministic_qwen3_8b.json
# [2026-08-31 10:30:15] [SAVED] output\results\Direkte Datenabfrage\12\plan-based_qwen3_8b.json
# [2026-08-31 10:30:30] [SAVED] output\results\Direkte Datenabfrage\12\iterative_qwen3_8b.json
# [2026-08-31 10:30:37] [SAVED] output\results\Direkte Datenabfrage\13\deterministic_qwen3_8b.json
# [2026-08-31 10:30:48] [SAVED] output\results\Direkte Datenabfrage\13\plan-based_qwen3_8b.json
# [2026-08-31 10:31:05] [SAVED] output\results\Direkte Datenabfrage\13\iterative_qwen3_8b.json
# [2026-08-31 10:31:12] [SAVED] output\results\Direkte Datenabfrage\14\deterministic_qwen3_8b.json
# [2026-08-31 10:31:19] [SAVED] output\results\Direkte Datenabfrage\14\plan-based_qwen3_8b.json
# [2026-08-31 10:31:33] [SAVED] output\results\Direkte Datenabfrage\14\iterative_qwen3_8b.json
# [2026-08-31 10:31:40] [SAVED] output\results\Direkte Datenabfrage\15\deterministic_qwen3_8b.json
# [2026-08-31 10:31:48] [SAVED] output\results\Direkte Datenabfrage\15\plan-based_qwen3_8b.json
# [2026-08-31 10:32:06] [SAVED] output\results\Direkte Datenabfrage\15\iterative_qwen3_8b.json
# [2026-08-31 10:32:15] [SAVED] output\results\Direkte Datenabfrage\16\deterministic_qwen3_8b.json
# [2026-08-31 10:32:28] [SAVED] output\results\Direkte Datenabfrage\16\plan-based_qwen3_8b.json
# [2026-08-31 10:32:45] [SAVED] output\results\Direkte Datenabfrage\16\iterative_qwen3_8b.json
# [2026-08-31 10:32:52] [SAVED] output\results\Direkte Datenabfrage\17\deterministic_qwen3_8b.json
# [2026-08-31 10:33:09] [SAVED] output\results\Direkte Datenabfrage\17\plan-based_qwen3_8b.json
# [2026-08-31 10:33:31] [SAVED] output\results\Direkte Datenabfrage\17\iterative_qwen3_8b.json
# [2026-08-31 10:33:40] [SAVED] output\results\Direkte Datenabfrage\18\deterministic_qwen3_8b.json
# [2026-08-31 10:33:53] [SAVED] output\results\Direkte Datenabfrage\18\plan-based_qwen3_8b.json
# [2026-08-31 10:34:08] [SAVED] output\results\Direkte Datenabfrage\18\iterative_qwen3_8b.json
# [2026-08-31 10:34:20] [SAVED] output\results\Direkte Datenabfrage\19\deterministic_qwen3_8b.json
# [2026-08-31 10:34:27] [SAVED] output\results\Direkte Datenabfrage\19\plan-based_qwen3_8b.json
# [2026-08-31 10:36:02] [SAVED] output\results\Direkte Datenabfrage\19\iterative_qwen3_8b.json
# [2026-08-31 10:36:13] [SAVED] output\results\Direkte Datenabfrage\20\deterministic_qwen3_8b.json
# [2026-08-31 10:36:30] [SAVED] output\results\Direkte Datenabfrage\20\plan-based_qwen3_8b.json
# [2026-08-31 10:36:48] [SAVED] output\results\Direkte Datenabfrage\20\iterative_qwen3_8b.json
# [2026-08-31 10:38:48] [SAVED] output\results\Direkte Datenabfrage\21\deterministic_qwen3_8b.json
# [2026-08-31 10:40:48] [SAVED] output\results\Direkte Datenabfrage\21\plan-based_qwen3_8b.json
# [2026-08-31 10:42:48] [SAVED] output\results\Direkte Datenabfrage\21\iterative_qwen3_8b.json
# [2026-08-31 10:42:56] [SAVED] output\results\Direkte Datenabfrage\22\deterministic_qwen3_8b.json
# [2026-08-31 10:43:05] [SAVED] output\results\Direkte Datenabfrage\22\plan-based_qwen3_8b.json
# [2026-08-31 10:43:19] [SAVED] output\results\Direkte Datenabfrage\22\iterative_qwen3_8b.json
# [2026-08-31 10:43:28] [SAVED] output\results\Direkte Datenabfrage\23\deterministic_qwen3_8b.json
# [2026-08-31 10:43:36] [SAVED] output\results\Direkte Datenabfrage\23\plan-based_qwen3_8b.json
# [2026-08-31 10:43:54] [SAVED] output\results\Direkte Datenabfrage\23\iterative_qwen3_8b.json
# [2026-08-31 10:45:54] [SAVED] output\results\Direkte Datenabfrage\24\deterministic_qwen3_8b.json
# [2026-08-31 10:46:06] [SAVED] output\results\Direkte Datenabfrage\24\plan-based_qwen3_8b.json
# [2026-08-31 10:46:23] [SAVED] output\results\Direkte Datenabfrage\24\iterative_qwen3_8b.json
# [2026-08-31 10:46:30] [SAVED] output\results\Direkte Datenabfrage\25\deterministic_qwen3_8b.json
# [2026-08-31 10:46:39] [SAVED] output\results\Direkte Datenabfrage\25\plan-based_qwen3_8b.json
# [2026-08-31 10:46:56] [SAVED] output\results\Direkte Datenabfrage\25\iterative_qwen3_8b.json
# [2026-08-31 10:47:03] [SAVED] output\results\Direkte Datenabfrage\26\deterministic_qwen3_8b.json
# [2026-08-31 10:47:10] [SAVED] output\results\Direkte Datenabfrage\26\plan-based_qwen3_8b.json
# [2026-08-31 10:47:19] [SAVED] output\results\Direkte Datenabfrage\26\iterative_qwen3_8b.json
# [2026-08-31 10:47:28] [SAVED] output\results\Direkte Datenabfrage\27\deterministic_qwen3_8b.json
# [2026-08-31 10:49:28] [SAVED] output\results\Direkte Datenabfrage\27\plan-based_qwen3_8b.json
# [2026-08-31 10:49:37] [SAVED] output\results\Direkte Datenabfrage\27\iterative_qwen3_8b.json
# [2026-08-31 10:49:43] [SAVED] output\results\Direkte Datenabfrage\28\deterministic_qwen3_8b.json
# [2026-08-31 10:49:49] [SAVED] output\results\Direkte Datenabfrage\28\plan-based_qwen3_8b.json
# [2026-08-31 10:49:55] [SAVED] output\results\Direkte Datenabfrage\28\iterative_qwen3_8b.json
# [2026-08-31 10:50:02] [SAVED] output\results\Direkte Datenabfrage\29\deterministic_qwen3_8b.json
# [2026-08-31 10:50:09] [SAVED] output\results\Direkte Datenabfrage\29\plan-based_qwen3_8b.json
# [2026-08-31 10:50:17] [SAVED] output\results\Direkte Datenabfrage\29\iterative_qwen3_8b.json
# [2026-08-31 10:50:22] [SAVED] output\results\Direkte Datenabfrage\30\deterministic_qwen3_8b.json
# [2026-08-31 10:50:30] [SAVED] output\results\Direkte Datenabfrage\30\plan-based_qwen3_8b.json
# [2026-08-31 10:50:38] [SAVED] output\results\Direkte Datenabfrage\30\iterative_qwen3_8b.json
# [2026-08-31 10:50:48] [SAVED] output\results\Einzelquellenverarbeitung\31\deterministic_qwen3_8b.json
# [2026-08-31 10:51:08] [SAVED] output\results\Einzelquellenverarbeitung\31\plan-based_qwen3_8b.json
# [2026-08-31 10:51:26] [SAVED] output\results\Einzelquellenverarbeitung\31\iterative_qwen3_8b.json
# [2026-08-31 10:51:35] [SAVED] output\results\Einzelquellenverarbeitung\32\deterministic_qwen3_8b.json
# [2026-08-31 10:51:54] [SAVED] output\results\Einzelquellenverarbeitung\32\plan-based_qwen3_8b.json
# [2026-08-31 10:52:11] [SAVED] output\results\Einzelquellenverarbeitung\32\iterative_qwen3_8b.json
# [2026-08-31 10:52:40] [SAVED] output\results\Einzelquellenverarbeitung\33\deterministic_qwen3_8b.json
# [2026-08-31 10:52:55] [SAVED] output\results\Einzelquellenverarbeitung\33\plan-based_qwen3_8b.json
# [2026-08-31 10:53:24] [SAVED] output\results\Einzelquellenverarbeitung\33\iterative_qwen3_8b.json
# [2026-08-31 10:55:24] [SAVED] output\results\Einzelquellenverarbeitung\34\deterministic_qwen3_8b.json
# [2026-08-31 10:57:24] [SAVED] output\results\Einzelquellenverarbeitung\34\plan-based_qwen3_8b.json
# [2026-08-31 10:59:54] [SAVED] output\results\Einzelquellenverarbeitung\34\iterative_qwen3_8b.json
# [2026-08-31 11:00:15] [SAVED] output\results\Einzelquellenverarbeitung\35\deterministic_qwen3_8b.json
# [2026-08-31 11:00:28] [SAVED] output\results\Einzelquellenverarbeitung\35\plan-based_qwen3_8b.json
# [2026-08-31 11:00:44] [SAVED] output\results\Einzelquellenverarbeitung\35\iterative_qwen3_8b.json
# [2026-08-31 11:02:44] [SAVED] output\results\Einzelquellenverarbeitung\36\deterministic_qwen3_8b.json
# [2026-08-31 11:03:01] [SAVED] output\results\Einzelquellenverarbeitung\36\plan-based_qwen3_8b.json
# [2026-08-31 11:03:33] [SAVED] output\results\Einzelquellenverarbeitung\36\iterative_qwen3_8b.json
# [2026-08-31 11:03:52] [SAVED] output\results\Einzelquellenverarbeitung\37\deterministic_qwen3_8b.json
# [2026-08-31 11:04:16] [SAVED] output\results\Einzelquellenverarbeitung\37\plan-based_qwen3_8b.json
# [2026-08-31 11:04:55] [SAVED] output\results\Einzelquellenverarbeitung\37\iterative_qwen3_8b.json
# [2026-08-31 11:05:11] [SAVED] output\results\Einzelquellenverarbeitung\38\deterministic_qwen3_8b.json
# [2026-08-31 11:05:37] [SAVED] output\results\Einzelquellenverarbeitung\38\plan-based_qwen3_8b.json
# [2026-08-31 11:06:09] [SAVED] output\results\Einzelquellenverarbeitung\38\iterative_qwen3_8b.json
# [2026-08-31 11:06:20] [SAVED] output\results\Einzelquellenverarbeitung\39\deterministic_qwen3_8b.json
# [2026-08-31 11:06:30] [SAVED] output\results\Einzelquellenverarbeitung\39\plan-based_qwen3_8b.json
# [2026-08-31 11:06:54] [SAVED] output\results\Einzelquellenverarbeitung\39\iterative_qwen3_8b.json
# [2026-08-31 11:07:03] [SAVED] output\results\Einzelquellenverarbeitung\40\deterministic_qwen3_8b.json
# [2026-08-31 11:07:12] [SAVED] output\results\Einzelquellenverarbeitung\40\plan-based_qwen3_8b.json
# [2026-08-31 11:09:28] [SAVED] output\results\Einzelquellenverarbeitung\40\iterative_qwen3_8b.json
# [2026-08-31 11:09:43] [SAVED] output\results\Einzelquellenverarbeitung\41\deterministic_qwen3_8b.json
# [2026-08-31 11:10:01] [SAVED] output\results\Einzelquellenverarbeitung\41\plan-based_qwen3_8b.json
# [2026-08-31 11:10:41] [SAVED] output\results\Einzelquellenverarbeitung\41\iterative_qwen3_8b.json
# [2026-08-31 11:11:01] [SAVED] output\results\Einzelquellenverarbeitung\42\deterministic_qwen3_8b.json
# [2026-08-31 11:11:16] [SAVED] output\results\Einzelquellenverarbeitung\42\plan-based_qwen3_8b.json
# [2026-08-31 11:11:41] [SAVED] output\results\Einzelquellenverarbeitung\42\iterative_qwen3_8b.json
# [2026-08-31 11:11:51] [SAVED] output\results\Einzelquellenverarbeitung\43\deterministic_qwen3_8b.json
# [2026-08-31 11:13:51] [SAVED] output\results\Einzelquellenverarbeitung\43\plan-based_qwen3_8b.json
# [2026-08-31 11:14:11] [SAVED] output\results\Einzelquellenverarbeitung\43\iterative_qwen3_8b.json
# [2026-08-31 11:14:20] [SAVED] output\results\Einzelquellenverarbeitung\44\deterministic_qwen3_8b.json
# [2026-08-31 11:14:32] [SAVED] output\results\Einzelquellenverarbeitung\44\plan-based_qwen3_8b.json
# [2026-08-31 11:14:46] [SAVED] output\results\Einzelquellenverarbeitung\44\iterative_qwen3_8b.json
# [2026-08-31 11:16:46] [SAVED] output\results\Einzelquellenverarbeitung\45\deterministic_qwen3_8b.json
# [2026-08-31 11:16:59] [SAVED] output\results\Einzelquellenverarbeitung\45\plan-based_qwen3_8b.json
# [2026-08-31 11:18:59] [SAVED] output\results\Einzelquellenverarbeitung\45\iterative_qwen3_8b.json
# [2026-08-31 11:19:14] [SAVED] output\results\Einzelquellenverarbeitung\46\deterministic_qwen3_8b.json
# [2026-08-31 11:19:25] [SAVED] output\results\Einzelquellenverarbeitung\46\plan-based_qwen3_8b.json
# [2026-08-31 11:19:45] [SAVED] output\results\Einzelquellenverarbeitung\46\iterative_qwen3_8b.json
# [2026-08-31 11:21:45] [SAVED] output\results\Einzelquellenverarbeitung\47\deterministic_qwen3_8b.json
# [2026-08-31 11:22:04] [SAVED] output\results\Einzelquellenverarbeitung\47\plan-based_qwen3_8b.json
# [2026-08-31 11:22:14] [SAVED] output\results\Einzelquellenverarbeitung\47\iterative_qwen3_8b.json
# [2026-08-31 11:22:22] [SAVED] output\results\Einzelquellenverarbeitung\48\deterministic_qwen3_8b.json
# [2026-08-31 11:22:36] [SAVED] output\results\Einzelquellenverarbeitung\48\plan-based_qwen3_8b.json
# [2026-08-31 11:23:09] [SAVED] output\results\Einzelquellenverarbeitung\48\iterative_qwen3_8b.json
# [2026-08-31 11:25:09] [SAVED] output\results\Einzelquellenverarbeitung\49\deterministic_qwen3_8b.json
# [2026-08-31 11:25:21] [SAVED] output\results\Einzelquellenverarbeitung\49\plan-based_qwen3_8b.json
# [2026-08-31 11:25:33] [SAVED] output\results\Einzelquellenverarbeitung\49\iterative_qwen3_8b.json
# [2026-08-31 11:27:34] [SAVED] output\results\Einzelquellenverarbeitung\50\deterministic_qwen3_8b.json
# [2026-08-31 11:27:53] [SAVED] output\results\Einzelquellenverarbeitung\50\plan-based_qwen3_8b.json
# [2026-08-31 11:28:01] [SAVED] output\results\Einzelquellenverarbeitung\50\iterative_qwen3_8b.json
# [2026-08-31 11:28:11] [SAVED] output\results\Einzelquellenverarbeitung\51\deterministic_qwen3_8b.json
# [2026-08-31 11:28:22] [SAVED] output\results\Einzelquellenverarbeitung\51\plan-based_qwen3_8b.json
# [2026-08-31 11:28:33] [SAVED] output\results\Einzelquellenverarbeitung\51\iterative_qwen3_8b.json
# [2026-08-31 11:30:33] [SAVED] output\results\Einzelquellenverarbeitung\52\deterministic_qwen3_8b.json
# [2026-08-31 11:32:33] [SAVED] output\results\Einzelquellenverarbeitung\52\plan-based_qwen3_8b.json
# [2026-08-31 11:32:56] [SAVED] output\results\Einzelquellenverarbeitung\52\iterative_qwen3_8b.json
# [2026-08-31 11:33:09] [SAVED] output\results\Einzelquellenverarbeitung\53\deterministic_qwen3_8b.json
# [2026-08-31 11:33:28] [SAVED] output\results\Einzelquellenverarbeitung\53\plan-based_qwen3_8b.json
# [2026-08-31 11:33:40] [SAVED] output\results\Einzelquellenverarbeitung\53\iterative_qwen3_8b.json
# [2026-08-31 11:33:49] [SAVED] output\results\Einzelquellenverarbeitung\54\deterministic_qwen3_8b.json
# [2026-08-31 11:34:03] [SAVED] output\results\Einzelquellenverarbeitung\54\plan-based_qwen3_8b.json
# [2026-08-31 11:36:29] [SAVED] output\results\Einzelquellenverarbeitung\54\iterative_qwen3_8b.json
# [2026-08-31 11:36:42] [SAVED] output\results\Einzelquellenverarbeitung\55\deterministic_qwen3_8b.json
# [2026-08-31 11:36:55] [SAVED] output\results\Einzelquellenverarbeitung\55\plan-based_qwen3_8b.json
# [2026-08-31 11:37:06] [SAVED] output\results\Einzelquellenverarbeitung\55\iterative_qwen3_8b.json
# [2026-08-31 11:37:13] [SAVED] output\results\Einzelquellenverarbeitung\56\deterministic_qwen3_8b.json
# [2026-08-31 11:37:21] [SAVED] output\results\Einzelquellenverarbeitung\56\plan-based_qwen3_8b.json
# [2026-08-31 11:37:36] [SAVED] output\results\Einzelquellenverarbeitung\56\iterative_qwen3_8b.json
# [2026-08-31 11:39:37] [SAVED] output\results\Einzelquellenverarbeitung\57\deterministic_qwen3_8b.json
# [2026-08-31 11:41:37] [SAVED] output\results\Einzelquellenverarbeitung\57\plan-based_qwen3_8b.json
# [2026-08-31 11:43:37] [SAVED] output\results\Einzelquellenverarbeitung\57\iterative_qwen3_8b.json
# [2026-08-31 11:43:48] [SAVED] output\results\Einzelquellenverarbeitung\58\deterministic_qwen3_8b.json
# [2026-08-31 11:44:16] [SAVED] output\results\Einzelquellenverarbeitung\58\plan-based_qwen3_8b.json
# [2026-08-31 11:44:32] [SAVED] output\results\Einzelquellenverarbeitung\58\iterative_qwen3_8b.json
# [2026-08-31 11:46:32] [SAVED] output\results\Einzelquellenverarbeitung\59\deterministic_qwen3_8b.json
# [2026-08-31 11:46:55] [SAVED] output\results\Einzelquellenverarbeitung\59\plan-based_qwen3_8b.json
# [2026-08-31 11:47:17] [SAVED] output\results\Einzelquellenverarbeitung\59\iterative_qwen3_8b.json
# [2026-08-31 11:47:35] [SAVED] output\results\Einzelquellenverarbeitung\60\deterministic_qwen3_8b.json
# [2026-08-31 11:49:35] [SAVED] output\results\Einzelquellenverarbeitung\60\plan-based_qwen3_8b.json
# [2026-08-31 11:49:51] [SAVED] output\results\Einzelquellenverarbeitung\60\iterative_qwen3_8b.json
# [2026-08-31 11:50:09] [SAVED] output\results\Mehrquellenverarbeitung\61\deterministic_qwen3_8b.json
# [2026-08-31 11:50:36] [SAVED] output\results\Mehrquellenverarbeitung\61\plan-based_qwen3_8b.json
# [2026-08-31 11:50:51] [SAVED] output\results\Mehrquellenverarbeitung\61\iterative_qwen3_8b.json
# [2026-08-31 11:51:10] [SAVED] output\results\Mehrquellenverarbeitung\62\deterministic_qwen3_8b.json
# [2026-08-31 11:51:27] [SAVED] output\results\Mehrquellenverarbeitung\62\plan-based_qwen3_8b.json
# [2026-08-31 11:51:45] [SAVED] output\results\Mehrquellenverarbeitung\62\iterative_qwen3_8b.json
# [2026-08-31 11:53:45] [SAVED] output\results\Mehrquellenverarbeitung\63\deterministic_qwen3_8b.json
# [2026-08-31 11:54:11] [SAVED] output\results\Mehrquellenverarbeitung\63\plan-based_qwen3_8b.json
# [2026-08-31 11:56:11] [SAVED] output\results\Mehrquellenverarbeitung\63\iterative_qwen3_8b.json
# [2026-08-31 11:56:23] [SAVED] output\results\Mehrquellenverarbeitung\64\deterministic_qwen3_8b.json
# [2026-08-31 11:56:44] [SAVED] output\results\Mehrquellenverarbeitung\64\plan-based_qwen3_8b.json
# [2026-08-31 11:57:44] [SAVED] output\results\Mehrquellenverarbeitung\64\iterative_qwen3_8b.json
# [2026-08-31 11:59:44] [SAVED] output\results\Mehrquellenverarbeitung\65\deterministic_qwen3_8b.json
# [2026-08-31 12:00:05] [SAVED] output\results\Mehrquellenverarbeitung\65\plan-based_qwen3_8b.json
# [2026-08-31 12:00:23] [SAVED] output\results\Mehrquellenverarbeitung\65\iterative_qwen3_8b.json
# [2026-08-31 12:02:23] [SAVED] output\results\Mehrquellenverarbeitung\66\deterministic_qwen3_8b.json
# [2026-08-31 12:02:46] [SAVED] output\results\Mehrquellenverarbeitung\66\plan-based_qwen3_8b.json
# [2026-08-31 12:03:35] [SAVED] output\results\Mehrquellenverarbeitung\66\iterative_qwen3_8b.json
# [2026-08-31 12:03:46] [SAVED] output\results\Mehrquellenverarbeitung\67\deterministic_qwen3_8b.json
# [2026-08-31 12:04:05] [SAVED] output\results\Mehrquellenverarbeitung\67\plan-based_qwen3_8b.json
# [2026-08-31 12:04:18] [SAVED] output\results\Mehrquellenverarbeitung\67\iterative_qwen3_8b.json
# [2026-08-31 12:04:32] [SAVED] output\results\Mehrquellenverarbeitung\68\deterministic_qwen3_8b.json
# [2026-08-31 12:04:53] [SAVED] output\results\Mehrquellenverarbeitung\68\plan-based_qwen3_8b.json
# [2026-08-31 12:06:53] [SAVED] output\results\Mehrquellenverarbeitung\68\iterative_qwen3_8b.json
# [2026-08-31 12:08:53] [SAVED] output\results\Mehrquellenverarbeitung\69\deterministic_qwen3_8b.json
# [2026-08-31 12:09:16] [SAVED] output\results\Mehrquellenverarbeitung\69\plan-based_qwen3_8b.json
# [2026-08-31 12:09:44] [SAVED] output\results\Mehrquellenverarbeitung\69\iterative_qwen3_8b.json
# [2026-08-31 12:09:59] [SAVED] output\results\Mehrquellenverarbeitung\70\deterministic_qwen3_8b.json
# [2026-08-31 12:10:22] [SAVED] output\results\Mehrquellenverarbeitung\70\plan-based_qwen3_8b.json
# [2026-08-31 12:12:22] [SAVED] output\results\Mehrquellenverarbeitung\70\iterative_qwen3_8b.json
# [2026-08-31 12:12:31] [SAVED] output\results\Mehrquellenverarbeitung\71\deterministic_qwen3_8b.json
# [2026-08-31 12:12:52] [SAVED] output\results\Mehrquellenverarbeitung\71\plan-based_qwen3_8b.json
# [2026-08-31 12:13:13] [SAVED] output\results\Mehrquellenverarbeitung\71\iterative_qwen3_8b.json
# [2026-08-31 12:13:23] [SAVED] output\results\Mehrquellenverarbeitung\72\deterministic_qwen3_8b.json
# [2026-08-31 12:13:35] [SAVED] output\results\Mehrquellenverarbeitung\72\plan-based_qwen3_8b.json
# [2026-08-31 12:14:00] [SAVED] output\results\Mehrquellenverarbeitung\72\iterative_qwen3_8b.json
# [2026-08-31 12:14:11] [SAVED] output\results\Mehrquellenverarbeitung\73\deterministic_qwen3_8b.json
# [2026-08-31 12:14:27] [SAVED] output\results\Mehrquellenverarbeitung\73\plan-based_qwen3_8b.json
# [2026-08-31 12:14:39] [SAVED] output\results\Mehrquellenverarbeitung\73\iterative_qwen3_8b.json
# [2026-08-31 12:16:39] [SAVED] output\results\Mehrquellenverarbeitung\74\deterministic_qwen3_8b.json
# [2026-08-31 12:16:57] [SAVED] output\results\Mehrquellenverarbeitung\74\plan-based_qwen3_8b.json
# [2026-08-31 12:18:58] [SAVED] output\results\Mehrquellenverarbeitung\74\iterative_qwen3_8b.json
# [2026-08-31 12:19:16] [SAVED] output\results\Mehrquellenverarbeitung\75\deterministic_qwen3_8b.json
# [2026-08-31 12:19:33] [SAVED] output\results\Mehrquellenverarbeitung\75\plan-based_qwen3_8b.json
# [2026-08-31 12:20:12] [SAVED] output\results\Mehrquellenverarbeitung\75\iterative_qwen3_8b.json
# [2026-08-31 12:20:30] [SAVED] output\results\Mehrquellenverarbeitung\76\deterministic_qwen3_8b.json
# [2026-08-31 12:22:30] [SAVED] output\results\Mehrquellenverarbeitung\76\plan-based_qwen3_8b.json
# [2026-08-31 12:22:46] [SAVED] output\results\Mehrquellenverarbeitung\76\iterative_qwen3_8b.json
# [2026-08-31 12:22:55] [SAVED] output\results\Mehrquellenverarbeitung\77\deterministic_qwen3_8b.json
# [2026-08-31 12:23:18] [SAVED] output\results\Mehrquellenverarbeitung\77\plan-based_qwen3_8b.json
# [2026-08-31 12:24:00] [SAVED] output\results\Mehrquellenverarbeitung\77\iterative_qwen3_8b.json
# [2026-08-31 12:24:31] [SAVED] output\results\Mehrquellenverarbeitung\78\deterministic_qwen3_8b.json
# [2026-08-31 12:24:42] [SAVED] output\results\Mehrquellenverarbeitung\78\plan-based_qwen3_8b.json
# [2026-08-31 12:25:17] [SAVED] output\results\Mehrquellenverarbeitung\78\iterative_qwen3_8b.json
# [2026-08-31 12:25:37] [SAVED] output\results\Mehrquellenverarbeitung\79\deterministic_qwen3_8b.json
# [2026-08-31 12:27:37] [SAVED] output\results\Mehrquellenverarbeitung\79\plan-based_qwen3_8b.json
# [2026-08-31 12:29:37] [SAVED] output\results\Mehrquellenverarbeitung\79\iterative_qwen3_8b.json
# [2026-08-31 12:29:52] [SAVED] output\results\Mehrquellenverarbeitung\80\deterministic_qwen3_8b.json
# [2026-08-31 12:30:14] [SAVED] output\results\Mehrquellenverarbeitung\80\plan-based_qwen3_8b.json
# [2026-08-31 12:32:14] [SAVED] output\results\Mehrquellenverarbeitung\80\iterative_qwen3_8b.json
# [2026-08-31 12:34:14] [SAVED] output\results\Mehrquellenverarbeitung\81\deterministic_qwen3_8b.json
# [2026-08-31 12:36:14] [SAVED] output\results\Mehrquellenverarbeitung\81\plan-based_qwen3_8b.json
# [2026-08-31 12:38:14] [SAVED] output\results\Mehrquellenverarbeitung\81\iterative_qwen3_8b.json
# [2026-08-31 12:38:22] [SAVED] output\results\Mehrquellenverarbeitung\82\deterministic_qwen3_8b.json
# [2026-08-31 12:40:22] [SAVED] output\results\Mehrquellenverarbeitung\82\plan-based_qwen3_8b.json
# [2026-08-31 12:42:22] [SAVED] output\results\Mehrquellenverarbeitung\82\iterative_qwen3_8b.json
# [2026-08-31 12:42:40] [SAVED] output\results\Mehrquellenverarbeitung\83\deterministic_qwen3_8b.json
# [2026-08-31 12:44:40] [SAVED] output\results\Mehrquellenverarbeitung\83\plan-based_qwen3_8b.json
# [2026-08-31 12:46:40] [SAVED] output\results\Mehrquellenverarbeitung\83\iterative_qwen3_8b.json
# [2026-08-31 12:46:55] [SAVED] output\results\Mehrquellenverarbeitung\84\deterministic_qwen3_8b.json
# [2026-08-31 12:48:55] [SAVED] output\results\Mehrquellenverarbeitung\84\plan-based_qwen3_8b.json
# [2026-08-31 12:50:55] [SAVED] output\results\Mehrquellenverarbeitung\84\iterative_qwen3_8b.json
# [2026-08-31 12:52:55] [SAVED] output\results\Mehrquellenverarbeitung\85\deterministic_qwen3_8b.json
# [2026-08-31 12:54:56] [SAVED] output\results\Mehrquellenverarbeitung\85\plan-based_qwen3_8b.json
# [2026-08-31 12:56:56] [SAVED] output\results\Mehrquellenverarbeitung\85\iterative_qwen3_8b.json
# [2026-08-31 12:57:16] [SAVED] output\results\Mehrquellenverarbeitung\86\deterministic_qwen3_8b.json
# [2026-08-31 12:59:16] [SAVED] output\results\Mehrquellenverarbeitung\86\plan-based_qwen3_8b.json
# [2026-08-31 13:01:16] [SAVED] output\results\Mehrquellenverarbeitung\86\iterative_qwen3_8b.json
# [2026-08-31 13:01:34] [SAVED] output\results\Mehrquellenverarbeitung\87\deterministic_qwen3_8b.json
# [2026-08-31 13:03:34] [SAVED] output\results\Mehrquellenverarbeitung\87\plan-based_qwen3_8b.json
# [2026-08-31 13:05:34] [SAVED] output\results\Mehrquellenverarbeitung\87\iterative_qwen3_8b.json
# [2026-08-31 13:07:34] [SAVED] output\results\Mehrquellenverarbeitung\88\deterministic_qwen3_8b.json
# [2026-08-31 13:09:34] [SAVED] output\results\Mehrquellenverarbeitung\88\plan-based_qwen3_8b.json
# [2026-08-31 13:11:52] [SAVED] output\results\Mehrquellenverarbeitung\88\iterative_qwen3_8b.json
# [2026-08-31 13:12:11] [SAVED] output\results\Mehrquellenverarbeitung\89\deterministic_qwen3_8b.json
# [2026-08-31 13:14:11] [SAVED] output\results\Mehrquellenverarbeitung\89\plan-based_qwen3_8b.json
# [2026-08-31 13:16:11] [SAVED] output\results\Mehrquellenverarbeitung\89\iterative_qwen3_8b.json
# [2026-08-31 13:16:28] [SAVED] output\results\Mehrquellenverarbeitung\90\deterministic_qwen3_8b.json
# [2026-08-31 13:18:28] [SAVED] output\results\Mehrquellenverarbeitung\90\plan-based_qwen3_8b.json
# [2026-08-31 13:20:43] [SAVED] output\results\Mehrquellenverarbeitung\90\iterative_qwen3_8b.json

# %%
# tasks = read_csv("tasks/tasks.csv")
# model = "qwen3:14b"

# for _, row in tasks.iterrows():
#     task_id = row["ID"]
#     task_type = row["Aufgabentyp"]
#     task = row["Aufgabe"]

#     method = "deterministic"
#     result = generate_result_for_task_with_method_1(task_id, task_type, task, model)
#     result_path = save_result_as_json(result, task_id, task_type, method, model)
#     print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] [SAVED] {result_path}")

#     method = "plan-based"
#     result = generate_result_for_task_with_method_2(task_id, task_type, task, model)
#     result_path = save_result_as_json(result, task_id, task_type, method, model)
#     print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] [SAVED] {result_path}")

#     method = "iterative"
#     result = generate_result_for_task_with_method_3(task_id, task_type, task, model)
#     result_path = save_result_as_json(result, task_id, task_type, method, model)
#     print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] [SAVED] {result_path}")

# %%
tasks = read_csv("tasks/tasks.csv")
model = "qwen3:30b"

for _, row in tasks.iterrows():
    task_id = row["ID"]
    task_type = row["Aufgabentyp"]
    task = row["Aufgabe"]

    method = "deterministic"
    result = generate_result_for_task_with_method_1(task_id, task_type, task, model)
    result_path = save_result_as_json(result, task_id, task_type, method, model)
    print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] [SAVED] {result_path}")

    method = "plan-based"
    result = generate_result_for_task_with_method_2(task_id, task_type, task, model)
    result_path = save_result_as_json(result, task_id, task_type, method, model)
    print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] [SAVED] {result_path}")

    method = "iterative"
    result = generate_result_for_task_with_method_3(task_id, task_type, task, model)
    result_path = save_result_as_json(result, task_id, task_type, method, model)
    print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] [SAVED] {result_path}")
# Out:
# [2026-08-31 16:48:24] [SAVED] output\results\Direkte Datenabfrage\1\deterministic_qwen3_30b.json
# [2026-08-31 16:48:36] [SAVED] output\results\Direkte Datenabfrage\1\plan-based_qwen3_30b.json
# [2026-08-31 16:48:47] [SAVED] output\results\Direkte Datenabfrage\1\iterative_qwen3_30b.json
# [2026-08-31 16:49:00] [SAVED] output\results\Direkte Datenabfrage\2\deterministic_qwen3_30b.json
# [2026-08-31 16:49:10] [SAVED] output\results\Direkte Datenabfrage\2\plan-based_qwen3_30b.json
# [2026-08-31 16:49:21] [SAVED] output\results\Direkte Datenabfrage\2\iterative_qwen3_30b.json
# [2026-08-31 16:49:27] [SAVED] output\results\Direkte Datenabfrage\3\deterministic_qwen3_30b.json
# [2026-08-31 16:51:27] [SAVED] output\results\Direkte Datenabfrage\3\plan-based_qwen3_30b.json
# [2026-08-31 16:51:32] [SAVED] output\results\Direkte Datenabfrage\3\iterative_qwen3_30b.json
# [2026-08-31 16:51:38] [SAVED] output\results\Direkte Datenabfrage\4\deterministic_qwen3_30b.json
# [2026-08-31 16:53:39] [SAVED] output\results\Direkte Datenabfrage\4\plan-based_qwen3_30b.json
# [2026-08-31 16:53:45] [SAVED] output\results\Direkte Datenabfrage\4\iterative_qwen3_30b.json
# [2026-08-31 16:53:50] [SAVED] output\results\Direkte Datenabfrage\5\deterministic_qwen3_30b.json
# [2026-08-31 16:55:50] [SAVED] output\results\Direkte Datenabfrage\5\plan-based_qwen3_30b.json
# [2026-08-31 16:55:55] [SAVED] output\results\Direkte Datenabfrage\5\iterative_qwen3_30b.json
# [2026-08-31 16:56:01] [SAVED] output\results\Direkte Datenabfrage\6\deterministic_qwen3_30b.json
# [2026-08-31 16:58:01] [SAVED] output\results\Direkte Datenabfrage\6\plan-based_qwen3_30b.json
# [2026-08-31 16:58:06] [SAVED] output\results\Direkte Datenabfrage\6\iterative_qwen3_30b.json
# [2026-08-31 16:58:19] [SAVED] output\results\Direkte Datenabfrage\7\deterministic_qwen3_30b.json
# [2026-08-31 16:58:30] [SAVED] output\results\Direkte Datenabfrage\7\plan-based_qwen3_30b.json
# [2026-08-31 16:58:40] [SAVED] output\results\Direkte Datenabfrage\7\iterative_qwen3_30b.json
# [2026-08-31 16:58:46] [SAVED] output\results\Direkte Datenabfrage\8\deterministic_qwen3_30b.json
# [2026-08-31 17:00:46] [SAVED] output\results\Direkte Datenabfrage\8\plan-based_qwen3_30b.json
# [2026-08-31 17:00:52] [SAVED] output\results\Direkte Datenabfrage\8\iterative_qwen3_30b.json
# [2026-08-31 17:00:59] [SAVED] output\results\Direkte Datenabfrage\9\deterministic_qwen3_30b.json
# [2026-08-31 17:02:59] [SAVED] output\results\Direkte Datenabfrage\9\plan-based_qwen3_30b.json
# [2026-08-31 17:03:05] [SAVED] output\results\Direkte Datenabfrage\9\iterative_qwen3_30b.json
# [2026-08-31 17:03:14] [SAVED] output\results\Direkte Datenabfrage\10\deterministic_qwen3_30b.json
# [2026-08-31 17:03:28] [SAVED] output\results\Direkte Datenabfrage\10\plan-based_qwen3_30b.json
# [2026-08-31 17:03:35] [SAVED] output\results\Direkte Datenabfrage\10\iterative_qwen3_30b.json
# [2026-08-31 17:03:48] [SAVED] output\results\Direkte Datenabfrage\11\deterministic_qwen3_30b.json
# [2026-08-31 17:04:00] [SAVED] output\results\Direkte Datenabfrage\11\plan-based_qwen3_30b.json
# [2026-08-31 17:04:14] [SAVED] output\results\Direkte Datenabfrage\11\iterative_qwen3_30b.json
# [2026-08-31 17:04:20] [SAVED] output\results\Direkte Datenabfrage\12\deterministic_qwen3_30b.json
# [2026-08-31 17:04:34] [SAVED] output\results\Direkte Datenabfrage\12\plan-based_qwen3_30b.json
# [2026-08-31 17:04:40] [SAVED] output\results\Direkte Datenabfrage\12\iterative_qwen3_30b.json
# [2026-08-31 17:04:46] [SAVED] output\results\Direkte Datenabfrage\13\deterministic_qwen3_30b.json
# [2026-08-31 17:06:46] [SAVED] output\results\Direkte Datenabfrage\13\plan-based_qwen3_30b.json
# [2026-08-31 17:06:52] [SAVED] output\results\Direkte Datenabfrage\13\iterative_qwen3_30b.json
# [2026-08-31 17:06:58] [SAVED] output\results\Direkte Datenabfrage\14\deterministic_qwen3_30b.json
# [2026-08-31 17:07:13] [SAVED] output\results\Direkte Datenabfrage\14\plan-based_qwen3_30b.json
# [2026-08-31 17:07:19] [SAVED] output\results\Direkte Datenabfrage\14\iterative_qwen3_30b.json
# [2026-08-31 17:07:25] [SAVED] output\results\Direkte Datenabfrage\15\deterministic_qwen3_30b.json
# [2026-08-31 17:09:25] [SAVED] output\results\Direkte Datenabfrage\15\plan-based_qwen3_30b.json
# [2026-08-31 17:09:34] [SAVED] output\results\Direkte Datenabfrage\15\iterative_qwen3_30b.json
# [2026-08-31 17:09:41] [SAVED] output\results\Direkte Datenabfrage\16\deterministic_qwen3_30b.json
# [2026-08-31 17:11:41] [SAVED] output\results\Direkte Datenabfrage\16\plan-based_qwen3_30b.json
# [2026-08-31 17:11:48] [SAVED] output\results\Direkte Datenabfrage\16\iterative_qwen3_30b.json
# [2026-08-31 17:11:56] [SAVED] output\results\Direkte Datenabfrage\17\deterministic_qwen3_30b.json
# [2026-08-31 17:12:08] [SAVED] output\results\Direkte Datenabfrage\17\plan-based_qwen3_30b.json
# [2026-08-31 17:12:17] [SAVED] output\results\Direkte Datenabfrage\17\iterative_qwen3_30b.json
# [2026-08-31 17:12:25] [SAVED] output\results\Direkte Datenabfrage\18\deterministic_qwen3_30b.json
# [2026-08-31 17:14:25] [SAVED] output\results\Direkte Datenabfrage\18\plan-based_qwen3_30b.json
# [2026-08-31 17:14:35] [SAVED] output\results\Direkte Datenabfrage\18\iterative_qwen3_30b.json
# [2026-08-31 17:14:45] [SAVED] output\results\Direkte Datenabfrage\19\deterministic_qwen3_30b.json
# [2026-08-31 17:14:59] [SAVED] output\results\Direkte Datenabfrage\19\plan-based_qwen3_30b.json
# [2026-08-31 17:15:09] [SAVED] output\results\Direkte Datenabfrage\19\iterative_qwen3_30b.json
# [2026-08-31 17:15:16] [SAVED] output\results\Direkte Datenabfrage\20\deterministic_qwen3_30b.json
# [2026-08-31 17:17:16] [SAVED] output\results\Direkte Datenabfrage\20\plan-based_qwen3_30b.json
# [2026-08-31 17:17:25] [SAVED] output\results\Direkte Datenabfrage\20\iterative_qwen3_30b.json
# [2026-08-31 17:19:25] [SAVED] output\results\Direkte Datenabfrage\21\deterministic_qwen3_30b.json
# [2026-08-31 17:21:25] [SAVED] output\results\Direkte Datenabfrage\21\plan-based_qwen3_30b.json
# [2026-08-31 17:23:25] [SAVED] output\results\Direkte Datenabfrage\21\iterative_qwen3_30b.json
# [2026-08-31 17:23:33] [SAVED] output\results\Direkte Datenabfrage\22\deterministic_qwen3_30b.json
# [2026-08-31 17:25:33] [SAVED] output\results\Direkte Datenabfrage\22\plan-based_qwen3_30b.json
# [2026-08-31 17:25:41] [SAVED] output\results\Direkte Datenabfrage\22\iterative_qwen3_30b.json
# [2026-08-31 17:27:41] [SAVED] output\results\Direkte Datenabfrage\23\deterministic_qwen3_30b.json
# [2026-08-31 17:29:41] [SAVED] output\results\Direkte Datenabfrage\23\plan-based_qwen3_30b.json
# [2026-08-31 17:29:49] [SAVED] output\results\Direkte Datenabfrage\23\iterative_qwen3_30b.json
# [2026-08-31 17:29:58] [SAVED] output\results\Direkte Datenabfrage\24\deterministic_qwen3_30b.json
# [2026-08-31 17:31:58] [SAVED] output\results\Direkte Datenabfrage\24\plan-based_qwen3_30b.json
# [2026-08-31 17:32:07] [SAVED] output\results\Direkte Datenabfrage\24\iterative_qwen3_30b.json
# [2026-08-31 17:32:14] [SAVED] output\results\Direkte Datenabfrage\25\deterministic_qwen3_30b.json
# [2026-08-31 17:32:30] [SAVED] output\results\Direkte Datenabfrage\25\plan-based_qwen3_30b.json
# [2026-08-31 17:32:37] [SAVED] output\results\Direkte Datenabfrage\25\iterative_qwen3_30b.json
# [2026-08-31 17:32:44] [SAVED] output\results\Direkte Datenabfrage\26\deterministic_qwen3_30b.json
# [2026-08-31 17:32:51] [SAVED] output\results\Direkte Datenabfrage\26\plan-based_qwen3_30b.json
# [2026-08-31 17:32:59] [SAVED] output\results\Direkte Datenabfrage\26\iterative_qwen3_30b.json
# [2026-08-31 17:33:06] [SAVED] output\results\Direkte Datenabfrage\27\deterministic_qwen3_30b.json
# [2026-08-31 17:33:20] [SAVED] output\results\Direkte Datenabfrage\27\plan-based_qwen3_30b.json
# [2026-08-31 17:35:20] [SAVED] output\results\Direkte Datenabfrage\27\iterative_qwen3_30b.json
# [2026-08-31 17:35:27] [SAVED] output\results\Direkte Datenabfrage\28\deterministic_qwen3_30b.json
# [2026-08-31 17:35:33] [SAVED] output\results\Direkte Datenabfrage\28\plan-based_qwen3_30b.json
# [2026-08-31 17:35:40] [SAVED] output\results\Direkte Datenabfrage\28\iterative_qwen3_30b.json
# [2026-08-31 17:35:48] [SAVED] output\results\Direkte Datenabfrage\29\deterministic_qwen3_30b.json
# [2026-08-31 17:35:54] [SAVED] output\results\Direkte Datenabfrage\29\plan-based_qwen3_30b.json
# [2026-08-31 17:36:01] [SAVED] output\results\Direkte Datenabfrage\29\iterative_qwen3_30b.json
# [2026-08-31 17:36:07] [SAVED] output\results\Direkte Datenabfrage\30\deterministic_qwen3_30b.json
# [2026-08-31 17:36:17] [SAVED] output\results\Direkte Datenabfrage\30\plan-based_qwen3_30b.json
# [2026-08-31 17:36:25] [SAVED] output\results\Direkte Datenabfrage\30\iterative_qwen3_30b.json
# [2026-08-31 17:36:37] [SAVED] output\results\Einzelquellenverarbeitung\31\deterministic_qwen3_30b.json
# [2026-08-31 17:36:48] [SAVED] output\results\Einzelquellenverarbeitung\31\plan-based_qwen3_30b.json
# [2026-08-31 17:36:57] [SAVED] output\results\Einzelquellenverarbeitung\31\iterative_qwen3_30b.json
# [2026-08-31 17:37:05] [SAVED] output\results\Einzelquellenverarbeitung\32\deterministic_qwen3_30b.json
# [2026-08-31 17:37:22] [SAVED] output\results\Einzelquellenverarbeitung\32\plan-based_qwen3_30b.json
# [2026-08-31 17:39:36] [SAVED] output\results\Einzelquellenverarbeitung\32\iterative_qwen3_30b.json
# [2026-08-31 17:39:49] [SAVED] output\results\Einzelquellenverarbeitung\33\deterministic_qwen3_30b.json
# [2026-08-31 17:41:49] [SAVED] output\results\Einzelquellenverarbeitung\33\plan-based_qwen3_30b.json
# [2026-08-31 17:42:17] [SAVED] output\results\Einzelquellenverarbeitung\33\iterative_qwen3_30b.json
# [2026-08-31 17:42:32] [SAVED] output\results\Einzelquellenverarbeitung\34\deterministic_qwen3_30b.json
# [2026-08-31 17:42:44] [SAVED] output\results\Einzelquellenverarbeitung\34\plan-based_qwen3_30b.json
# [2026-08-31 17:45:01] [SAVED] output\results\Einzelquellenverarbeitung\34\iterative_qwen3_30b.json
# [2026-08-31 17:45:13] [SAVED] output\results\Einzelquellenverarbeitung\35\deterministic_qwen3_30b.json
# [2026-08-31 17:45:26] [SAVED] output\results\Einzelquellenverarbeitung\35\plan-based_qwen3_30b.json
# [2026-08-31 17:45:39] [SAVED] output\results\Einzelquellenverarbeitung\35\iterative_qwen3_30b.json
# [2026-08-31 17:45:53] [SAVED] output\results\Einzelquellenverarbeitung\36\deterministic_qwen3_30b.json
# [2026-08-31 17:47:53] [SAVED] output\results\Einzelquellenverarbeitung\36\plan-based_qwen3_30b.json
# [2026-08-31 17:50:22] [SAVED] output\results\Einzelquellenverarbeitung\36\iterative_qwen3_30b.json
# [2026-08-31 17:50:36] [SAVED] output\results\Einzelquellenverarbeitung\37\deterministic_qwen3_30b.json
# [2026-08-31 17:50:49] [SAVED] output\results\Einzelquellenverarbeitung\37\plan-based_qwen3_30b.json
# [2026-08-31 17:51:04] [SAVED] output\results\Einzelquellenverarbeitung\37\iterative_qwen3_30b.json
# [2026-08-31 17:51:22] [SAVED] output\results\Einzelquellenverarbeitung\38\deterministic_qwen3_30b.json
# [2026-08-31 17:53:22] [SAVED] output\results\Einzelquellenverarbeitung\38\plan-based_qwen3_30b.json
# [2026-08-31 17:55:37] [SAVED] output\results\Einzelquellenverarbeitung\38\iterative_qwen3_30b.json
# [2026-08-31 17:55:45] [SAVED] output\results\Einzelquellenverarbeitung\39\deterministic_qwen3_30b.json
# [2026-08-31 17:55:54] [SAVED] output\results\Einzelquellenverarbeitung\39\plan-based_qwen3_30b.json
# [2026-08-31 17:56:05] [SAVED] output\results\Einzelquellenverarbeitung\39\iterative_qwen3_30b.json
# [2026-08-31 17:56:21] [SAVED] output\results\Einzelquellenverarbeitung\40\deterministic_qwen3_30b.json
# [2026-08-31 17:56:38] [SAVED] output\results\Einzelquellenverarbeitung\40\plan-based_qwen3_30b.json
# [2026-08-31 17:58:48] [SAVED] output\results\Einzelquellenverarbeitung\40\iterative_qwen3_30b.json
# [2026-08-31 18:00:48] [SAVED] output\results\Einzelquellenverarbeitung\41\deterministic_qwen3_30b.json
# [2026-08-31 18:01:05] [SAVED] output\results\Einzelquellenverarbeitung\41\plan-based_qwen3_30b.json
# [2026-08-31 18:03:05] [SAVED] output\results\Einzelquellenverarbeitung\41\iterative_qwen3_30b.json
# [2026-08-31 18:05:06] [SAVED] output\results\Einzelquellenverarbeitung\42\deterministic_qwen3_30b.json
# [2026-08-31 18:07:06] [SAVED] output\results\Einzelquellenverarbeitung\42\plan-based_qwen3_30b.json
# [2026-08-31 18:09:19] [SAVED] output\results\Einzelquellenverarbeitung\42\iterative_qwen3_30b.json
# [2026-08-31 18:09:29] [SAVED] output\results\Einzelquellenverarbeitung\43\deterministic_qwen3_30b.json
# [2026-08-31 18:11:29] [SAVED] output\results\Einzelquellenverarbeitung\43\plan-based_qwen3_30b.json
# [2026-08-31 18:13:47] [SAVED] output\results\Einzelquellenverarbeitung\43\iterative_qwen3_30b.json
# [2026-08-31 18:13:56] [SAVED] output\results\Einzelquellenverarbeitung\44\deterministic_qwen3_30b.json
# [2026-08-31 18:15:56] [SAVED] output\results\Einzelquellenverarbeitung\44\plan-based_qwen3_30b.json
# [2026-08-31 18:18:40] [SAVED] output\results\Einzelquellenverarbeitung\44\iterative_qwen3_30b.json
# [2026-08-31 18:18:51] [SAVED] output\results\Einzelquellenverarbeitung\45\deterministic_qwen3_30b.json
# [2026-08-31 18:20:51] [SAVED] output\results\Einzelquellenverarbeitung\45\plan-based_qwen3_30b.json
# [2026-08-31 18:23:19] [SAVED] output\results\Einzelquellenverarbeitung\45\iterative_qwen3_30b.json
# [2026-08-31 18:23:32] [SAVED] output\results\Einzelquellenverarbeitung\46\deterministic_qwen3_30b.json
# [2026-08-31 18:25:32] [SAVED] output\results\Einzelquellenverarbeitung\46\plan-based_qwen3_30b.json
# [2026-08-31 18:27:49] [SAVED] output\results\Einzelquellenverarbeitung\46\iterative_qwen3_30b.json
# [2026-08-31 18:28:03] [SAVED] output\results\Einzelquellenverarbeitung\47\deterministic_qwen3_30b.json
# [2026-08-31 18:30:03] [SAVED] output\results\Einzelquellenverarbeitung\47\plan-based_qwen3_30b.json
# [2026-08-31 18:32:03] [SAVED] output\results\Einzelquellenverarbeitung\47\iterative_qwen3_30b.json
# [2026-08-31 18:32:18] [SAVED] output\results\Einzelquellenverarbeitung\48\deterministic_qwen3_30b.json
# [2026-08-31 18:34:18] [SAVED] output\results\Einzelquellenverarbeitung\48\plan-based_qwen3_30b.json
# [2026-08-31 18:36:49] [SAVED] output\results\Einzelquellenverarbeitung\48\iterative_qwen3_30b.json
# [2026-08-31 18:38:49] [SAVED] output\results\Einzelquellenverarbeitung\49\deterministic_qwen3_30b.json
# [2026-08-31 18:40:49] [SAVED] output\results\Einzelquellenverarbeitung\49\plan-based_qwen3_30b.json
# [2026-08-31 18:43:32] [SAVED] output\results\Einzelquellenverarbeitung\49\iterative_qwen3_30b.json
# [2026-08-31 18:43:42] [SAVED] output\results\Einzelquellenverarbeitung\50\deterministic_qwen3_30b.json
# [2026-08-31 18:43:51] [SAVED] output\results\Einzelquellenverarbeitung\50\plan-based_qwen3_30b.json
# [2026-08-31 18:44:01] [SAVED] output\results\Einzelquellenverarbeitung\50\iterative_qwen3_30b.json
# [2026-08-31 18:44:10] [SAVED] output\results\Einzelquellenverarbeitung\51\deterministic_qwen3_30b.json
# [2026-08-31 18:46:10] [SAVED] output\results\Einzelquellenverarbeitung\51\plan-based_qwen3_30b.json
# [2026-08-31 18:48:24] [SAVED] output\results\Einzelquellenverarbeitung\51\iterative_qwen3_30b.json
# [2026-08-31 18:48:36] [SAVED] output\results\Einzelquellenverarbeitung\52\deterministic_qwen3_30b.json
# [2026-08-31 18:48:48] [SAVED] output\results\Einzelquellenverarbeitung\52\plan-based_qwen3_30b.json
# [2026-08-31 18:49:00] [SAVED] output\results\Einzelquellenverarbeitung\52\iterative_qwen3_30b.json
# [2026-08-31 18:49:13] [SAVED] output\results\Einzelquellenverarbeitung\53\deterministic_qwen3_30b.json
# [2026-08-31 18:51:13] [SAVED] output\results\Einzelquellenverarbeitung\53\plan-based_qwen3_30b.json
# [2026-08-31 18:53:40] [SAVED] output\results\Einzelquellenverarbeitung\53\iterative_qwen3_30b.json
# [2026-08-31 18:53:49] [SAVED] output\results\Einzelquellenverarbeitung\54\deterministic_qwen3_30b.json
# [2026-08-31 18:55:49] [SAVED] output\results\Einzelquellenverarbeitung\54\plan-based_qwen3_30b.json
# [2026-08-31 18:57:08] [SAVED] output\results\Einzelquellenverarbeitung\54\iterative_qwen3_30b.json
# [2026-08-31 18:57:19] [SAVED] output\results\Einzelquellenverarbeitung\55\deterministic_qwen3_30b.json
# [2026-08-31 18:59:19] [SAVED] output\results\Einzelquellenverarbeitung\55\plan-based_qwen3_30b.json
# [2026-08-31 19:02:20] [SAVED] output\results\Einzelquellenverarbeitung\55\iterative_qwen3_30b.json
# [2026-08-31 19:02:27] [SAVED] output\results\Einzelquellenverarbeitung\56\deterministic_qwen3_30b.json
# [2026-08-31 19:02:33] [SAVED] output\results\Einzelquellenverarbeitung\56\plan-based_qwen3_30b.json
# [2026-08-31 19:02:40] [SAVED] output\results\Einzelquellenverarbeitung\56\iterative_qwen3_30b.json
# [2026-08-31 19:02:52] [SAVED] output\results\Einzelquellenverarbeitung\57\deterministic_qwen3_30b.json
# [2026-08-31 19:04:52] [SAVED] output\results\Einzelquellenverarbeitung\57\plan-based_qwen3_30b.json
# [2026-08-31 19:05:00] [SAVED] output\results\Einzelquellenverarbeitung\57\iterative_qwen3_30b.json
# [2026-08-31 19:05:10] [SAVED] output\results\Einzelquellenverarbeitung\58\deterministic_qwen3_30b.json
# [2026-08-31 19:07:10] [SAVED] output\results\Einzelquellenverarbeitung\58\plan-based_qwen3_30b.json
# [2026-08-31 19:09:10] [SAVED] output\results\Einzelquellenverarbeitung\58\iterative_qwen3_30b.json
# [2026-08-31 19:11:10] [SAVED] output\results\Einzelquellenverarbeitung\59\deterministic_qwen3_30b.json
# [2026-08-31 19:13:10] [SAVED] output\results\Einzelquellenverarbeitung\59\plan-based_qwen3_30b.json
# [2026-08-31 19:15:10] [SAVED] output\results\Einzelquellenverarbeitung\59\iterative_qwen3_30b.json
# [2026-08-31 19:17:10] [SAVED] output\results\Einzelquellenverarbeitung\60\deterministic_qwen3_30b.json
# [2026-08-31 19:19:10] [SAVED] output\results\Einzelquellenverarbeitung\60\plan-based_qwen3_30b.json
# [2026-08-31 19:21:10] [SAVED] output\results\Einzelquellenverarbeitung\60\iterative_qwen3_30b.json
# [2026-08-31 19:21:23] [SAVED] output\results\Mehrquellenverarbeitung\61\deterministic_qwen3_30b.json
# [2026-08-31 19:23:23] [SAVED] output\results\Mehrquellenverarbeitung\61\plan-based_qwen3_30b.json
# [2026-08-31 19:25:23] [SAVED] output\results\Mehrquellenverarbeitung\61\iterative_qwen3_30b.json
# [2026-08-31 19:25:33] [SAVED] output\results\Mehrquellenverarbeitung\62\deterministic_qwen3_30b.json
# [2026-08-31 19:27:33] [SAVED] output\results\Mehrquellenverarbeitung\62\plan-based_qwen3_30b.json
# [2026-08-31 19:29:50] [SAVED] output\results\Mehrquellenverarbeitung\62\iterative_qwen3_30b.json
# [2026-08-31 19:31:50] [SAVED] output\results\Mehrquellenverarbeitung\63\deterministic_qwen3_30b.json
# [2026-08-31 19:33:50] [SAVED] output\results\Mehrquellenverarbeitung\63\plan-based_qwen3_30b.json
# [2026-08-31 19:34:04] [SAVED] output\results\Mehrquellenverarbeitung\63\iterative_qwen3_30b.json
# [2026-08-31 19:34:13] [SAVED] output\results\Mehrquellenverarbeitung\64\deterministic_qwen3_30b.json
# [2026-08-31 19:36:13] [SAVED] output\results\Mehrquellenverarbeitung\64\plan-based_qwen3_30b.json
# [2026-08-31 19:38:44] [SAVED] output\results\Mehrquellenverarbeitung\64\iterative_qwen3_30b.json
# [2026-08-31 19:40:44] [SAVED] output\results\Mehrquellenverarbeitung\65\deterministic_qwen3_30b.json
# [2026-08-31 19:42:44] [SAVED] output\results\Mehrquellenverarbeitung\65\plan-based_qwen3_30b.json
# [2026-08-31 19:44:44] [SAVED] output\results\Mehrquellenverarbeitung\65\iterative_qwen3_30b.json
# [2026-08-31 19:44:55] [SAVED] output\results\Mehrquellenverarbeitung\66\deterministic_qwen3_30b.json
# [2026-08-31 19:46:55] [SAVED] output\results\Mehrquellenverarbeitung\66\plan-based_qwen3_30b.json
# [2026-08-31 19:48:55] [SAVED] output\results\Mehrquellenverarbeitung\66\iterative_qwen3_30b.json
# [2026-08-31 19:49:03] [SAVED] output\results\Mehrquellenverarbeitung\67\deterministic_qwen3_30b.json
# [2026-08-31 19:51:04] [SAVED] output\results\Mehrquellenverarbeitung\67\plan-based_qwen3_30b.json
# [2026-08-31 19:51:19] [SAVED] output\results\Mehrquellenverarbeitung\67\iterative_qwen3_30b.json
# [2026-08-31 19:53:19] [SAVED] output\results\Mehrquellenverarbeitung\68\deterministic_qwen3_30b.json
# [2026-08-31 19:55:19] [SAVED] output\results\Mehrquellenverarbeitung\68\plan-based_qwen3_30b.json
# [2026-08-31 19:57:19] [SAVED] output\results\Mehrquellenverarbeitung\68\iterative_qwen3_30b.json
# [2026-08-31 19:57:37] [SAVED] output\results\Mehrquellenverarbeitung\69\deterministic_qwen3_30b.json
# [2026-08-31 19:59:37] [SAVED] output\results\Mehrquellenverarbeitung\69\plan-based_qwen3_30b.json
# [2026-08-31 20:01:37] [SAVED] output\results\Mehrquellenverarbeitung\69\iterative_qwen3_30b.json
# [2026-08-31 20:01:49] [SAVED] output\results\Mehrquellenverarbeitung\70\deterministic_qwen3_30b.json
# [2026-08-31 20:03:49] [SAVED] output\results\Mehrquellenverarbeitung\70\plan-based_qwen3_30b.json
# [2026-08-31 20:05:49] [SAVED] output\results\Mehrquellenverarbeitung\70\iterative_qwen3_30b.json
# [2026-08-31 20:05:59] [SAVED] output\results\Mehrquellenverarbeitung\71\deterministic_qwen3_30b.json
# [2026-08-31 20:07:59] [SAVED] output\results\Mehrquellenverarbeitung\71\plan-based_qwen3_30b.json
# [2026-08-31 20:08:17] [SAVED] output\results\Mehrquellenverarbeitung\71\iterative_qwen3_30b.json
# [2026-08-31 20:08:36] [SAVED] output\results\Mehrquellenverarbeitung\72\deterministic_qwen3_30b.json
# [2026-08-31 20:10:36] [SAVED] output\results\Mehrquellenverarbeitung\72\plan-based_qwen3_30b.json
# [2026-08-31 20:12:36] [SAVED] output\results\Mehrquellenverarbeitung\72\iterative_qwen3_30b.json
# [2026-08-31 20:12:49] [SAVED] output\results\Mehrquellenverarbeitung\73\deterministic_qwen3_30b.json
# [2026-08-31 20:14:49] [SAVED] output\results\Mehrquellenverarbeitung\73\plan-based_qwen3_30b.json
# [2026-08-31 20:16:49] [SAVED] output\results\Mehrquellenverarbeitung\73\iterative_qwen3_30b.json
# [2026-08-31 20:18:49] [SAVED] output\results\Mehrquellenverarbeitung\74\deterministic_qwen3_30b.json
# [2026-08-31 20:19:01] [SAVED] output\results\Mehrquellenverarbeitung\74\plan-based_qwen3_30b.json
# [2026-08-31 20:19:12] [SAVED] output\results\Mehrquellenverarbeitung\74\iterative_qwen3_30b.json
# [2026-08-31 20:21:12] [SAVED] output\results\Mehrquellenverarbeitung\75\deterministic_qwen3_30b.json
# [2026-08-31 20:23:12] [SAVED] output\results\Mehrquellenverarbeitung\75\plan-based_qwen3_30b.json
# [2026-08-31 20:25:12] [SAVED] output\results\Mehrquellenverarbeitung\75\iterative_qwen3_30b.json
# [2026-08-31 20:27:12] [SAVED] output\results\Mehrquellenverarbeitung\76\deterministic_qwen3_30b.json
# [2026-08-31 20:29:12] [SAVED] output\results\Mehrquellenverarbeitung\76\plan-based_qwen3_30b.json
# [2026-08-31 20:31:12] [SAVED] output\results\Mehrquellenverarbeitung\76\iterative_qwen3_30b.json
# [2026-08-31 20:31:20] [SAVED] output\results\Mehrquellenverarbeitung\77\deterministic_qwen3_30b.json
# [2026-08-31 20:33:20] [SAVED] output\results\Mehrquellenverarbeitung\77\plan-based_qwen3_30b.json
# [2026-08-31 20:35:20] [SAVED] output\results\Mehrquellenverarbeitung\77\iterative_qwen3_30b.json
# [2026-08-31 20:35:29] [SAVED] output\results\Mehrquellenverarbeitung\78\deterministic_qwen3_30b.json
# [2026-08-31 20:37:29] [SAVED] output\results\Mehrquellenverarbeitung\78\plan-based_qwen3_30b.json
# [2026-08-31 20:40:02] [SAVED] output\results\Mehrquellenverarbeitung\78\iterative_qwen3_30b.json
# [2026-08-31 20:40:18] [SAVED] output\results\Mehrquellenverarbeitung\79\deterministic_qwen3_30b.json
# [2026-08-31 20:40:31] [SAVED] output\results\Mehrquellenverarbeitung\79\plan-based_qwen3_30b.json
# [2026-08-31 20:42:31] [SAVED] output\results\Mehrquellenverarbeitung\79\iterative_qwen3_30b.json
# [2026-08-31 20:44:31] [SAVED] output\results\Mehrquellenverarbeitung\80\deterministic_qwen3_30b.json
# [2026-08-31 20:46:31] [SAVED] output\results\Mehrquellenverarbeitung\80\plan-based_qwen3_30b.json
# [2026-08-31 20:48:31] [SAVED] output\results\Mehrquellenverarbeitung\80\iterative_qwen3_30b.json
# [2026-08-31 20:50:31] [SAVED] output\results\Mehrquellenverarbeitung\81\deterministic_qwen3_30b.json
# [2026-08-31 20:50:44] [SAVED] output\results\Mehrquellenverarbeitung\81\plan-based_qwen3_30b.json
# [2026-08-31 20:52:44] [SAVED] output\results\Mehrquellenverarbeitung\81\iterative_qwen3_30b.json
# [2026-08-31 20:52:52] [SAVED] output\results\Mehrquellenverarbeitung\82\deterministic_qwen3_30b.json
# [2026-08-31 20:54:52] [SAVED] output\results\Mehrquellenverarbeitung\82\plan-based_qwen3_30b.json
# [2026-08-31 20:55:10] [SAVED] output\results\Mehrquellenverarbeitung\82\iterative_qwen3_30b.json
# [2026-08-31 20:55:25] [SAVED] output\results\Mehrquellenverarbeitung\83\deterministic_qwen3_30b.json
# [2026-08-31 20:57:25] [SAVED] output\results\Mehrquellenverarbeitung\83\plan-based_qwen3_30b.json
# [2026-08-31 20:59:25] [SAVED] output\results\Mehrquellenverarbeitung\83\iterative_qwen3_30b.json
# [2026-08-31 20:59:38] [SAVED] output\results\Mehrquellenverarbeitung\84\deterministic_qwen3_30b.json
# [2026-08-31 21:01:38] [SAVED] output\results\Mehrquellenverarbeitung\84\plan-based_qwen3_30b.json
# [2026-08-31 21:03:38] [SAVED] output\results\Mehrquellenverarbeitung\84\iterative_qwen3_30b.json
# [2026-08-31 21:03:59] [SAVED] output\results\Mehrquellenverarbeitung\85\deterministic_qwen3_30b.json
# [2026-08-31 21:05:59] [SAVED] output\results\Mehrquellenverarbeitung\85\plan-based_qwen3_30b.json
# [2026-08-31 21:07:59] [SAVED] output\results\Mehrquellenverarbeitung\85\iterative_qwen3_30b.json
# [2026-08-31 21:09:59] [SAVED] output\results\Mehrquellenverarbeitung\86\deterministic_qwen3_30b.json
# [2026-08-31 21:11:59] [SAVED] output\results\Mehrquellenverarbeitung\86\plan-based_qwen3_30b.json
# [2026-08-31 21:13:59] [SAVED] output\results\Mehrquellenverarbeitung\86\iterative_qwen3_30b.json
# [2026-08-31 21:15:59] [SAVED] output\results\Mehrquellenverarbeitung\87\deterministic_qwen3_30b.json
# [2026-08-31 21:17:59] [SAVED] output\results\Mehrquellenverarbeitung\87\plan-based_qwen3_30b.json
# [2026-08-31 21:19:59] [SAVED] output\results\Mehrquellenverarbeitung\87\iterative_qwen3_30b.json
# [2026-08-31 21:22:00] [SAVED] output\results\Mehrquellenverarbeitung\88\deterministic_qwen3_30b.json
# [2026-08-31 21:24:00] [SAVED] output\results\Mehrquellenverarbeitung\88\plan-based_qwen3_30b.json
# [2026-08-31 21:26:00] [SAVED] output\results\Mehrquellenverarbeitung\88\iterative_qwen3_30b.json
# [2026-08-31 21:28:00] [SAVED] output\results\Mehrquellenverarbeitung\89\deterministic_qwen3_30b.json
# [2026-08-31 21:30:00] [SAVED] output\results\Mehrquellenverarbeitung\89\plan-based_qwen3_30b.json
# [2026-08-31 21:32:00] [SAVED] output\results\Mehrquellenverarbeitung\89\iterative_qwen3_30b.json
# [2026-08-31 21:34:00] [SAVED] output\results\Mehrquellenverarbeitung\90\deterministic_qwen3_30b.json
# [2026-08-31 21:36:00] [SAVED] output\results\Mehrquellenverarbeitung\90\plan-based_qwen3_30b.json
# [2026-08-31 21:38:00] [SAVED] output\results\Mehrquellenverarbeitung\90\iterative_qwen3_30b.json

# %%
tasks = read_csv("tasks/tasks.csv")
model = "gpt-5.4-mini-2026-03-17"

for _, row in tasks.iterrows():
    task_id = row["ID"]
    task_type = row["Aufgabentyp"]
    task = row["Aufgabe"]

    method = "deterministic"
    result = generate_result_for_task_with_method_1(task_id, task_type, task, model)
    result_path = save_result_as_json(result, task_id, task_type, method, model)
    print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] [SAVED] {result_path}")

    method = "plan-based"
    result = generate_result_for_task_with_method_2(task_id, task_type, task, model)
    result_path = save_result_as_json(result, task_id, task_type, method, model)
    print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] [SAVED] {result_path}")

    method = "iterative"
    result = generate_result_for_task_with_method_3(task_id, task_type, task, model)
    result_path = save_result_as_json(result, task_id, task_type, method, model)
    print(f"[{datetime.now():%Y-%m-%d %H:%M:%S}] [SAVED] {result_path}")
# Out:
# [2026-08-31 23:50:54] [SAVED] output\results\Direkte Datenabfrage\1\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:50:56] [SAVED] output\results\Direkte Datenabfrage\1\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:50:58] [SAVED] output\results\Direkte Datenabfrage\1\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:00] [SAVED] output\results\Direkte Datenabfrage\2\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:02] [SAVED] output\results\Direkte Datenabfrage\2\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:04] [SAVED] output\results\Direkte Datenabfrage\2\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:06] [SAVED] output\results\Direkte Datenabfrage\3\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:07] [SAVED] output\results\Direkte Datenabfrage\3\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:09] [SAVED] output\results\Direkte Datenabfrage\3\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:11] [SAVED] output\results\Direkte Datenabfrage\4\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:13] [SAVED] output\results\Direkte Datenabfrage\4\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:15] [SAVED] output\results\Direkte Datenabfrage\4\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:16] [SAVED] output\results\Direkte Datenabfrage\5\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:18] [SAVED] output\results\Direkte Datenabfrage\5\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:20] [SAVED] output\results\Direkte Datenabfrage\5\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:21] [SAVED] output\results\Direkte Datenabfrage\6\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:23] [SAVED] output\results\Direkte Datenabfrage\6\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:25] [SAVED] output\results\Direkte Datenabfrage\6\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:26] [SAVED] output\results\Direkte Datenabfrage\7\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:28] [SAVED] output\results\Direkte Datenabfrage\7\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:30] [SAVED] output\results\Direkte Datenabfrage\7\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:32] [SAVED] output\results\Direkte Datenabfrage\8\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:33] [SAVED] output\results\Direkte Datenabfrage\8\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:35] [SAVED] output\results\Direkte Datenabfrage\8\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:37] [SAVED] output\results\Direkte Datenabfrage\9\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:39] [SAVED] output\results\Direkte Datenabfrage\9\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:41] [SAVED] output\results\Direkte Datenabfrage\9\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:42] [SAVED] output\results\Direkte Datenabfrage\10\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:45] [SAVED] output\results\Direkte Datenabfrage\10\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:48] [SAVED] output\results\Direkte Datenabfrage\10\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:49] [SAVED] output\results\Direkte Datenabfrage\11\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:51] [SAVED] output\results\Direkte Datenabfrage\11\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:53] [SAVED] output\results\Direkte Datenabfrage\11\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:55] [SAVED] output\results\Direkte Datenabfrage\12\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:56] [SAVED] output\results\Direkte Datenabfrage\12\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:51:58] [SAVED] output\results\Direkte Datenabfrage\12\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:00] [SAVED] output\results\Direkte Datenabfrage\13\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:01] [SAVED] output\results\Direkte Datenabfrage\13\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:03] [SAVED] output\results\Direkte Datenabfrage\13\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:05] [SAVED] output\results\Direkte Datenabfrage\14\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:07] [SAVED] output\results\Direkte Datenabfrage\14\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:09] [SAVED] output\results\Direkte Datenabfrage\14\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:11] [SAVED] output\results\Direkte Datenabfrage\15\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:13] [SAVED] output\results\Direkte Datenabfrage\15\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:14] [SAVED] output\results\Direkte Datenabfrage\15\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:16] [SAVED] output\results\Direkte Datenabfrage\16\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:18] [SAVED] output\results\Direkte Datenabfrage\16\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:20] [SAVED] output\results\Direkte Datenabfrage\16\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:21] [SAVED] output\results\Direkte Datenabfrage\17\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:23] [SAVED] output\results\Direkte Datenabfrage\17\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:24] [SAVED] output\results\Direkte Datenabfrage\17\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:28] [SAVED] output\results\Direkte Datenabfrage\18\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:30] [SAVED] output\results\Direkte Datenabfrage\18\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:32] [SAVED] output\results\Direkte Datenabfrage\18\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:33] [SAVED] output\results\Direkte Datenabfrage\19\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:35] [SAVED] output\results\Direkte Datenabfrage\19\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:37] [SAVED] output\results\Direkte Datenabfrage\19\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:38] [SAVED] output\results\Direkte Datenabfrage\20\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:40] [SAVED] output\results\Direkte Datenabfrage\20\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:42] [SAVED] output\results\Direkte Datenabfrage\20\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:43] [SAVED] output\results\Direkte Datenabfrage\21\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:45] [SAVED] output\results\Direkte Datenabfrage\21\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:47] [SAVED] output\results\Direkte Datenabfrage\21\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:49] [SAVED] output\results\Direkte Datenabfrage\22\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:52] [SAVED] output\results\Direkte Datenabfrage\22\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:54] [SAVED] output\results\Direkte Datenabfrage\22\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:55] [SAVED] output\results\Direkte Datenabfrage\23\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:57] [SAVED] output\results\Direkte Datenabfrage\23\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:52:59] [SAVED] output\results\Direkte Datenabfrage\23\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:00] [SAVED] output\results\Direkte Datenabfrage\24\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:02] [SAVED] output\results\Direkte Datenabfrage\24\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:04] [SAVED] output\results\Direkte Datenabfrage\24\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:06] [SAVED] output\results\Direkte Datenabfrage\25\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:08] [SAVED] output\results\Direkte Datenabfrage\25\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:10] [SAVED] output\results\Direkte Datenabfrage\25\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:12] [SAVED] output\results\Direkte Datenabfrage\26\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:14] [SAVED] output\results\Direkte Datenabfrage\26\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:15] [SAVED] output\results\Direkte Datenabfrage\26\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:17] [SAVED] output\results\Direkte Datenabfrage\27\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:19] [SAVED] output\results\Direkte Datenabfrage\27\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:21] [SAVED] output\results\Direkte Datenabfrage\27\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:22] [SAVED] output\results\Direkte Datenabfrage\28\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:24] [SAVED] output\results\Direkte Datenabfrage\28\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:26] [SAVED] output\results\Direkte Datenabfrage\28\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:27] [SAVED] output\results\Direkte Datenabfrage\29\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:29] [SAVED] output\results\Direkte Datenabfrage\29\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:31] [SAVED] output\results\Direkte Datenabfrage\29\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:33] [SAVED] output\results\Direkte Datenabfrage\30\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:34] [SAVED] output\results\Direkte Datenabfrage\30\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:36] [SAVED] output\results\Direkte Datenabfrage\30\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:38] [SAVED] output\results\Einzelquellenverarbeitung\31\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:40] [SAVED] output\results\Einzelquellenverarbeitung\31\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:42] [SAVED] output\results\Einzelquellenverarbeitung\31\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:44] [SAVED] output\results\Einzelquellenverarbeitung\32\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:46] [SAVED] output\results\Einzelquellenverarbeitung\32\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:48] [SAVED] output\results\Einzelquellenverarbeitung\32\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:49] [SAVED] output\results\Einzelquellenverarbeitung\33\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:51] [SAVED] output\results\Einzelquellenverarbeitung\33\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:53] [SAVED] output\results\Einzelquellenverarbeitung\33\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:54] [SAVED] output\results\Einzelquellenverarbeitung\34\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:56] [SAVED] output\results\Einzelquellenverarbeitung\34\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:53:58] [SAVED] output\results\Einzelquellenverarbeitung\34\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:00] [SAVED] output\results\Einzelquellenverarbeitung\35\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:02] [SAVED] output\results\Einzelquellenverarbeitung\35\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:04] [SAVED] output\results\Einzelquellenverarbeitung\35\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:05] [SAVED] output\results\Einzelquellenverarbeitung\36\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:07] [SAVED] output\results\Einzelquellenverarbeitung\36\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:09] [SAVED] output\results\Einzelquellenverarbeitung\36\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:11] [SAVED] output\results\Einzelquellenverarbeitung\37\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:13] [SAVED] output\results\Einzelquellenverarbeitung\37\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:15] [SAVED] output\results\Einzelquellenverarbeitung\37\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:17] [SAVED] output\results\Einzelquellenverarbeitung\38\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:19] [SAVED] output\results\Einzelquellenverarbeitung\38\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:21] [SAVED] output\results\Einzelquellenverarbeitung\38\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:22] [SAVED] output\results\Einzelquellenverarbeitung\39\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:24] [SAVED] output\results\Einzelquellenverarbeitung\39\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:26] [SAVED] output\results\Einzelquellenverarbeitung\39\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:28] [SAVED] output\results\Einzelquellenverarbeitung\40\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:30] [SAVED] output\results\Einzelquellenverarbeitung\40\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:32] [SAVED] output\results\Einzelquellenverarbeitung\40\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:33] [SAVED] output\results\Einzelquellenverarbeitung\41\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:35] [SAVED] output\results\Einzelquellenverarbeitung\41\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:37] [SAVED] output\results\Einzelquellenverarbeitung\41\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:39] [SAVED] output\results\Einzelquellenverarbeitung\42\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:41] [SAVED] output\results\Einzelquellenverarbeitung\42\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:43] [SAVED] output\results\Einzelquellenverarbeitung\42\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:44] [SAVED] output\results\Einzelquellenverarbeitung\43\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:47] [SAVED] output\results\Einzelquellenverarbeitung\43\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:48] [SAVED] output\results\Einzelquellenverarbeitung\43\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:50] [SAVED] output\results\Einzelquellenverarbeitung\44\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:52] [SAVED] output\results\Einzelquellenverarbeitung\44\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:54] [SAVED] output\results\Einzelquellenverarbeitung\44\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:56] [SAVED] output\results\Einzelquellenverarbeitung\45\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:54:58] [SAVED] output\results\Einzelquellenverarbeitung\45\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:00] [SAVED] output\results\Einzelquellenverarbeitung\45\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:02] [SAVED] output\results\Einzelquellenverarbeitung\46\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:04] [SAVED] output\results\Einzelquellenverarbeitung\46\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:06] [SAVED] output\results\Einzelquellenverarbeitung\46\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:08] [SAVED] output\results\Einzelquellenverarbeitung\47\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:10] [SAVED] output\results\Einzelquellenverarbeitung\47\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:12] [SAVED] output\results\Einzelquellenverarbeitung\47\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:14] [SAVED] output\results\Einzelquellenverarbeitung\48\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:16] [SAVED] output\results\Einzelquellenverarbeitung\48\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:18] [SAVED] output\results\Einzelquellenverarbeitung\48\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:20] [SAVED] output\results\Einzelquellenverarbeitung\49\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:22] [SAVED] output\results\Einzelquellenverarbeitung\49\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:24] [SAVED] output\results\Einzelquellenverarbeitung\49\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:26] [SAVED] output\results\Einzelquellenverarbeitung\50\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:28] [SAVED] output\results\Einzelquellenverarbeitung\50\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:30] [SAVED] output\results\Einzelquellenverarbeitung\50\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:32] [SAVED] output\results\Einzelquellenverarbeitung\51\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:34] [SAVED] output\results\Einzelquellenverarbeitung\51\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:36] [SAVED] output\results\Einzelquellenverarbeitung\51\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:38] [SAVED] output\results\Einzelquellenverarbeitung\52\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:40] [SAVED] output\results\Einzelquellenverarbeitung\52\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:44] [SAVED] output\results\Einzelquellenverarbeitung\52\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:46] [SAVED] output\results\Einzelquellenverarbeitung\53\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:48] [SAVED] output\results\Einzelquellenverarbeitung\53\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:50] [SAVED] output\results\Einzelquellenverarbeitung\53\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:51] [SAVED] output\results\Einzelquellenverarbeitung\54\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:54] [SAVED] output\results\Einzelquellenverarbeitung\54\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:56] [SAVED] output\results\Einzelquellenverarbeitung\54\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:55:58] [SAVED] output\results\Einzelquellenverarbeitung\55\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:00] [SAVED] output\results\Einzelquellenverarbeitung\55\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:02] [SAVED] output\results\Einzelquellenverarbeitung\55\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:04] [SAVED] output\results\Einzelquellenverarbeitung\56\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:06] [SAVED] output\results\Einzelquellenverarbeitung\56\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:09] [SAVED] output\results\Einzelquellenverarbeitung\56\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:11] [SAVED] output\results\Einzelquellenverarbeitung\57\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:13] [SAVED] output\results\Einzelquellenverarbeitung\57\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:15] [SAVED] output\results\Einzelquellenverarbeitung\57\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:17] [SAVED] output\results\Einzelquellenverarbeitung\58\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:20] [SAVED] output\results\Einzelquellenverarbeitung\58\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:22] [SAVED] output\results\Einzelquellenverarbeitung\58\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:24] [SAVED] output\results\Einzelquellenverarbeitung\59\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:26] [SAVED] output\results\Einzelquellenverarbeitung\59\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:28] [SAVED] output\results\Einzelquellenverarbeitung\59\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:30] [SAVED] output\results\Einzelquellenverarbeitung\60\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:32] [SAVED] output\results\Einzelquellenverarbeitung\60\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:34] [SAVED] output\results\Einzelquellenverarbeitung\60\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:36] [SAVED] output\results\Mehrquellenverarbeitung\61\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:39] [SAVED] output\results\Mehrquellenverarbeitung\61\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:41] [SAVED] output\results\Mehrquellenverarbeitung\61\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:42] [SAVED] output\results\Mehrquellenverarbeitung\62\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:45] [SAVED] output\results\Mehrquellenverarbeitung\62\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:47] [SAVED] output\results\Mehrquellenverarbeitung\62\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:49] [SAVED] output\results\Mehrquellenverarbeitung\63\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:51] [SAVED] output\results\Mehrquellenverarbeitung\63\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:54] [SAVED] output\results\Mehrquellenverarbeitung\63\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:56] [SAVED] output\results\Mehrquellenverarbeitung\64\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:56:58] [SAVED] output\results\Mehrquellenverarbeitung\64\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:57:00] [SAVED] output\results\Mehrquellenverarbeitung\64\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:57:02] [SAVED] output\results\Mehrquellenverarbeitung\65\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:57:04] [SAVED] output\results\Mehrquellenverarbeitung\65\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:57:06] [SAVED] output\results\Mehrquellenverarbeitung\65\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:57:08] [SAVED] output\results\Mehrquellenverarbeitung\66\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:57:10] [SAVED] output\results\Mehrquellenverarbeitung\66\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:57:12] [SAVED] output\results\Mehrquellenverarbeitung\66\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:57:14] [SAVED] output\results\Mehrquellenverarbeitung\67\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:57:17] [SAVED] output\results\Mehrquellenverarbeitung\67\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:57:19] [SAVED] output\results\Mehrquellenverarbeitung\67\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:57:21] [SAVED] output\results\Mehrquellenverarbeitung\68\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:57:22] [SAVED] output\results\Mehrquellenverarbeitung\68\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:57:25] [SAVED] output\results\Mehrquellenverarbeitung\68\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:57:27] [SAVED] output\results\Mehrquellenverarbeitung\69\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:57:28] [SAVED] output\results\Mehrquellenverarbeitung\69\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:57:31] [SAVED] output\results\Mehrquellenverarbeitung\69\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:57:32] [SAVED] output\results\Mehrquellenverarbeitung\70\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:57:35] [SAVED] output\results\Mehrquellenverarbeitung\70\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:57:41] [SAVED] output\results\Mehrquellenverarbeitung\70\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:57:43] [SAVED] output\results\Mehrquellenverarbeitung\71\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:57:45] [SAVED] output\results\Mehrquellenverarbeitung\71\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:57:47] [SAVED] output\results\Mehrquellenverarbeitung\71\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:57:49] [SAVED] output\results\Mehrquellenverarbeitung\72\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:57:51] [SAVED] output\results\Mehrquellenverarbeitung\72\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:57:53] [SAVED] output\results\Mehrquellenverarbeitung\72\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:57:55] [SAVED] output\results\Mehrquellenverarbeitung\73\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:57:58] [SAVED] output\results\Mehrquellenverarbeitung\73\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:00] [SAVED] output\results\Mehrquellenverarbeitung\73\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:02] [SAVED] output\results\Mehrquellenverarbeitung\74\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:04] [SAVED] output\results\Mehrquellenverarbeitung\74\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:06] [SAVED] output\results\Mehrquellenverarbeitung\74\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:08] [SAVED] output\results\Mehrquellenverarbeitung\75\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:10] [SAVED] output\results\Mehrquellenverarbeitung\75\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:12] [SAVED] output\results\Mehrquellenverarbeitung\75\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:16] [SAVED] output\results\Mehrquellenverarbeitung\76\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:18] [SAVED] output\results\Mehrquellenverarbeitung\76\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:20] [SAVED] output\results\Mehrquellenverarbeitung\76\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:22] [SAVED] output\results\Mehrquellenverarbeitung\77\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:24] [SAVED] output\results\Mehrquellenverarbeitung\77\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:27] [SAVED] output\results\Mehrquellenverarbeitung\77\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:29] [SAVED] output\results\Mehrquellenverarbeitung\78\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:31] [SAVED] output\results\Mehrquellenverarbeitung\78\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:33] [SAVED] output\results\Mehrquellenverarbeitung\78\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:35] [SAVED] output\results\Mehrquellenverarbeitung\79\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:37] [SAVED] output\results\Mehrquellenverarbeitung\79\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:39] [SAVED] output\results\Mehrquellenverarbeitung\79\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:41] [SAVED] output\results\Mehrquellenverarbeitung\80\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:43] [SAVED] output\results\Mehrquellenverarbeitung\80\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:45] [SAVED] output\results\Mehrquellenverarbeitung\80\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:47] [SAVED] output\results\Mehrquellenverarbeitung\81\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:49] [SAVED] output\results\Mehrquellenverarbeitung\81\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:51] [SAVED] output\results\Mehrquellenverarbeitung\81\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:52] [SAVED] output\results\Mehrquellenverarbeitung\82\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:55] [SAVED] output\results\Mehrquellenverarbeitung\82\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:57] [SAVED] output\results\Mehrquellenverarbeitung\82\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:58:59] [SAVED] output\results\Mehrquellenverarbeitung\83\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:59:01] [SAVED] output\results\Mehrquellenverarbeitung\83\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:59:04] [SAVED] output\results\Mehrquellenverarbeitung\83\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:59:05] [SAVED] output\results\Mehrquellenverarbeitung\84\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:59:07] [SAVED] output\results\Mehrquellenverarbeitung\84\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:59:09] [SAVED] output\results\Mehrquellenverarbeitung\84\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:59:11] [SAVED] output\results\Mehrquellenverarbeitung\85\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:59:14] [SAVED] output\results\Mehrquellenverarbeitung\85\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:59:16] [SAVED] output\results\Mehrquellenverarbeitung\85\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:59:19] [SAVED] output\results\Mehrquellenverarbeitung\86\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:59:21] [SAVED] output\results\Mehrquellenverarbeitung\86\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:59:23] [SAVED] output\results\Mehrquellenverarbeitung\86\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:59:25] [SAVED] output\results\Mehrquellenverarbeitung\87\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:59:28] [SAVED] output\results\Mehrquellenverarbeitung\87\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:59:30] [SAVED] output\results\Mehrquellenverarbeitung\87\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:59:33] [SAVED] output\results\Mehrquellenverarbeitung\88\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:59:36] [SAVED] output\results\Mehrquellenverarbeitung\88\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:59:38] [SAVED] output\results\Mehrquellenverarbeitung\88\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:59:40] [SAVED] output\results\Mehrquellenverarbeitung\89\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:59:42] [SAVED] output\results\Mehrquellenverarbeitung\89\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:59:44] [SAVED] output\results\Mehrquellenverarbeitung\89\iterative_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:59:47] [SAVED] output\results\Mehrquellenverarbeitung\90\deterministic_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:59:49] [SAVED] output\results\Mehrquellenverarbeitung\90\plan-based_gpt-5.4-mini-2026-03-17.json
# [2026-08-31 23:59:51] [SAVED] output\results\Mehrquellenverarbeitung\90\iterative_gpt-5.4-mini-2026-03-17.json
