# %% [markdown]
# # VL-Time

# %% [markdown]
# ### Imports

# %%
import os
import json
import base64
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ## Agents

# %% [markdown]
# ### Client

# %%
client = OpenAI()

# %% [markdown]
# ### Agent for analysing plots

# %%
prompt_for_plots = """
Du bist ein Experte für Energieverbrauchs-Zeitreihenanalyse.

Das Bild enthält eine oder mehrere Zeitreihen des Energieverbrauchs (kWh).
Jede Zeitreihe repräsentiert ein Energieverbrauchsprofil über die Zeit.

Analysiere jede Zeitreihe und klassifiziere sie in eine der folgenden Kategorien:
- Haushalt
- Büro
- Industrie / Fabrik
- Maschine / Anlage
- Unbekannt

Gehe dabei wie folgt vor:
1. Beschreibe das Verbrauchsmuster (Grundlast, Spitzenlast, Tagesmuster).
2. Identifiziere typische Nutzungszeiten.
3. Analysiere Variabilität und periodisches Verhalten.
4. Klassifiziere die Zeitreihe.
5. Begründe deine Entscheidung.

Wenn mehrere Zeitreihen vorhanden sind:
- Analysiere jede Zeitreihe einzeln.
- Vergleiche die Zeitreihen miteinander.
- Ordne jeder Zeitreihe eine Kategorie zu.
- Erstelle eine kurze Zusammenfassung.
"""

def analyse_plots(image_base64: str, prompt: str = prompt_for_plots, model: str = "gpt-4.1") -> str:
    response = client.chat.completions.create(
        model=model,
        messages=[
            {
                "role": "user",
                "content": [
                    {"type": "text", "text": prompt},
                    {
                        "type": "image_url",
                        "image_url": {
                            "url": f"data:image/png;base64,{image_base64}"
                        },
                    },
                ],
            }
        ],
    )

    return {
        "answer": response.choices[0].message.content,
        "prompt_tokens": response.usage.prompt_tokens,
        "completion_tokens": response.usage.completion_tokens,
        "total_tokens": response.usage.total_tokens,
        "model": model
    }

# %% [markdown]
# ### Agent for analysing arrays

# %%
prompt_for_arrays = """
Du bist ein Experte für Energieverbrauchs-Zeitreihenanalyse.

Du erhältst ein oder mehrere Arrays des Energieverbrauchs (kWh).
Jedes Array repräsentiert ein Energieverbrauchsprofil über die Zeit.

Analysiere jede Zeitreihe und klassifiziere sie in eine der folgenden Kategorien:
- Haushalt
- Büro
- Industrie / Fabrik
- Maschine / Anlage
- Unbekannt

Gehe dabei wie folgt vor:
1. Beschreibe das Verbrauchsmuster (Grundlast, Spitzenlast, Tagesmuster).
2. Identifiziere typische Nutzungszeiten.
3. Analysiere Variabilität und periodisches Verhalten.
4. Klassifiziere die Zeitreihe.
5. Begründe deine Entscheidung.

Wenn mehrere Zeitreihen vorhanden sind:
- Analysiere jede Zeitreihe einzeln.
- Vergleiche die Zeitreihen miteinander.
- Ordne jeder Zeitreihe eine Kategorie zu.
- Erstelle eine kurze Zusammenfassung.
"""

def array_dict_to_json(data: dict) -> str:
    converted = {}

    for key, value in data.items():
        if isinstance(value, np.ndarray):
            converted[key] = value.tolist()
        else:
            converted[key] = value

    return converted
    # return json.dumps(converted)

def analyse_arrays(data: dict, prompt: str = prompt_for_arrays, model="gpt-4.1") -> dict:
    json_string = array_dict_to_json(data)
    data_text = json.dumps(json_string, separators=(',', ':')) # indent=2

    response = client.chat.completions.create(
        model=model,
        messages=[
            {
                "role": "user",
                "content": f"{prompt}\n\nTime series data:\n{data_text}"
            }
        ],
    )

    return {
        "answer": response.choices[0].message.content,
        "prompt_tokens": response.usage.prompt_tokens,
        "completion_tokens": response.usage.completion_tokens,
        "total_tokens": response.usage.total_tokens,
    }

# %% [markdown]
# ## Eine Zeitreihe

# %% [markdown]
# ### Beispieldaten

# %%
# Beispiel: Energieverbrauch über 24 Stunden
hours = np.arange(0, 24, 0.25)

# Simulierter Verbrauch
consumption = (
    0.3 +                               # Grundlast
    0.5 * (hours > 6) * (hours < 9) +   # Morgen
    0.8 * (hours > 17) * (hours < 22) + # Abend
    0.1 * np.random.randn(len(hours))   # Rauschen
)

# ===== PLOT =====

plt.figure(figsize=(10,4))
plt.plot(hours, consumption)
plt.xlabel("Time (hours)")
plt.ylabel("Energy consumption (kWh)")
plt.title("Energy consumption over 24 hours")
plt.grid(True)
plt.savefig("energy_ts.png")
plt.close()

# Bild laden
with open("energy_ts.png", "rb") as f:
    energy_ts = base64.b64encode(f.read()).decode("utf-8")

# ===== DICT =====

times = pd.date_range(
    start="2025-01-01 00:00",
    periods=96,
    freq="15min"
)

times = times.strftime("%Y-%m-%d %H:%M").tolist()

energy_ts_dict = {
    "mp_1": {
        "unit": "kWh",
        "data": [
            [t, float(v)]
            for t, v in zip(times, consumption)
        ]
    }
}

# %% [markdown]
# ### Analyse mit Plot

# %%
result = analyse_plots(energy_ts)

print(f"prompt_tokens: {result['prompt_tokens']}")
print(f"completion_tokens: {result['completion_tokens']}")
print(f"total_tokens: {result['total_tokens']}")

print(result["answer"])
# Out:
# prompt_tokens: 640
# completion_tokens: 633
# total_tokens: 1273
# ### Analyse der gezeigten Zeitreihe
#
# #### 1. Verbrauchsmuster (Grundlast, Spitzenlast, Tagesmuster)
# - **Grundlast**: Es gibt eine sichtbare Grundlast, die in den Nachtstunden (ca. zwischen 0 und 6 Uhr sowie nach 22 Uhr) bei etwa 0,2 bis 0,4 kWh liegt.
# - **Spitzenlast**: Zwei deutlich erkennbare Spitzen treten im Bereich von ca. 7 bis 9 Uhr und noch markanter zwischen ca. 17 und 21 Uhr auf. In diesen Zeiträumen steigt der Verbrauch auf bis zu 1,3 kWh.
# - **Tagesmuster**: Typisch ist ein Energieverbrauch mit einer niedrigeren Grundlast in der Nacht, morgens ein Anstieg, tagsüber eine etwas ruhigere Phase und abends die höchste Spitze.
#
# #### 2. Typische Nutzungszeiten
# - **Morgens**: Erhöhte Last von ca. 7 bis 9 Uhr.
# - **Abends**: Sehr hohe Spitzen zwischen 17 und 21 Uhr.
# - **Nachts**: Verbrauch sinkt wieder deutlich ab, gering nach etwa 21 Uhr.
#
# #### 3. Variabilität und periodisches Verhalten
# - **Variabilität**: Besonders in den “Peak”-Zeiten treten starke Schwankungen auf, was u.a. durch das Ein- und Ausschalten mehrerer Verbraucher erklärbar ist.
# - **Periodizität**: Ein klares Tagesmuster ist erkennbar (typisch für Arbeits- oder Lebensrhythmen).
#
# #### 4. Klassifikation
# **Die Zeitreihe passt am besten zu:**
# - **Haushalt**
#
# #### 5. Begründung der Entscheidung
# - Das Tagesmuster mit dem typischen morgendlichen und abendlichen Spitzen (vor allem zwischen 17 und 21 Uhr) ist ein starker Indikator für einen Haushaltsverbrauch. Haushalte zeigen oft geringe Grundlast nachts, steigenden Verbrauch am Morgen (Frühstück, Aufstehen) sowie den Hauptverbrauch am Abend (Kochen, Haushaltsgeräte, Beleuchtung). Tagsüber ist der Verbrauch tendenziell niedriger, was mit der Abwesenheit der meisten Bewohner zusammenhängt. Das Muster unterscheidet sich deutlich von typischen Büro- oder Industrieprofilen, die eher tagsüber und weniger in den Abendstunden Spitzenlasten aufweisen.
#
# ---
#
# ### Zusammenfassung
#
# - **Einzige Zeitreihe**: Die Zeitreihe zeigt ein klassisches Haushaltsmuster mit deutlicher Abendspitze und morgendlichem Peak.
# - **Kategorie**: **Haushalt**
# - **Begründung**: Konsistent mit typischem Familien- oder Singlehaushalt, geringer Verbrauch nachts, Peaks morgens und abends, niedrige Werte tagsüber. Büros oder Industrieanlagen würden ein anderes Lastprofil zeigen, meist mit höheren Tagwerten und geringeren Abendspitzen.
#
# **Fazit:**
# **Die Zeitreihe ist eindeutig einem Haushalt (Wohnbereich) zuzuordnen.**

# %% [markdown]
# ### Analyse mit Array

# %%
result = analyse_arrays(energy_ts_dict)

print(f"prompt_tokens: {result['prompt_tokens']}")
print(f"completion_tokens: {result['completion_tokens']}")
print(f"total_tokens: {result['total_tokens']}")

print(result["answer"])
# Out:
# prompt_tokens: 2231
# completion_tokens: 731
# total_tokens: 2962
# **Analyse der Zeitreihe mp_1**
#
# **1. Beschreibung des Verbrauchsmusters (Grundlast, Spitzenlast, Tagesmuster)**
# - **Grundlast**: In den Nachtstunden (ca. 0:00 bis 5:30 Uhr) liegt der Verbrauch bei niedrigen Werten, meistens zwischen 0,13 und 0,55 kWh pro Viertelstunde.
# - **Spitzenlast**:
#     - **Morgens**: Ab 6:15 bis etwa 8:45 Uhr steigt der Verbrauch abrupt auf Werte von 0,8 bis 1,0 kWh je Viertelstunde.
#     - **Abends**: Zwischen 17:15 und 21:45 Uhr erhebliche Spitzen, oft über 1,0 kWh und teils noch höher bis ca. 1,17 kWh.
# - **Tagsüber**: Nach 9:00 bis zum Nachmittag (ca. 16:45 Uhr) pendelt der Verbrauch zwischen 0,2 und 0,5 kWh, abgesehen von den Spitzenzeiten.
#
# **2. Typische Nutzungszeiten**
# - **Frühmorgens (ca. 6:15–8:45)** und **Abends (ca. 17:15–21:45)** zeigen deutlich erhöhte Energieverbräuche.
# - In der Tagesmitte ist der Verbrauch gegenüber den Spitzenstunden wesentlich reduziert.
#
# **3. Analyse Variabilität und periodisches Verhalten**
# - **Variabilität**: Zwischen Alltag und "Spitzenzeiten" gibt es ausgeprägte Unterschiede im Verbrauch.
# - **Periodizität**: Es zeigt sich ein klares tageszeitliches Muster – zwei Hauptverbrauchsphasen (morgens und abends), ansonsten geringer Grundverbrauch.
# - Kein durchgängiger hoher Verbrauch über den Tag, keine extreme Schwankung wie sie typischerweise für Industrie- oder Maschinenbetrieb charakteristisch wäre.
#
# **4. Klassifikation der Zeitreihe**
# - **Kategorie:** Haushalt
#
# **5. Begründung der Entscheidung**
# - Das Muster mit niedriger Grundlast über Nacht und am Tag, sowie ausgeprägten Spitzen am Morgen und Abend ist typisch für private Haushalte. Es spiegelt typische Verhaltensmuster:
#     - Morgens werden Geräte beim Aufstehen genutzt (z.B. Wasserkocher, Kaffeemaschine, Beleuchtung, Dusche).
#     - Tagsüber sind wenige Personen anwesend – der Verbrauch sinkt.
#     - Am Abend erneuter starker Anstieg, wenn die Bewohner nach Hause kommen, kochen, Licht verwenden, Unterhaltungselektronik einschalten etc.
# - Das Muster passt nicht zu
#     - **Büro**: Hier läge die Hauptlast tagsüber.
#     - **Industrie/Maschine**: Hier wären entweder Ganztagesverbrauch oder starker Verbrauch während einer Schicht dominant, meist weniger ausgeprägte Morgen-Abend-Spitzen.
#     - **Unbekannt**: Das Muster ist für Haushalt sehr charakteristisch.
#
# ---
#
# **Vergleich und Zusammenfassung**
# - Es liegt nur eine Zeitreihe vor.
# - Die Zeitreihe zeigt alle Hauptmerkmale eines Energieverbrauchsprofils eines Haushalts.
# - Die Auswertung lässt nahezu eindeutig auf "Haushalt" schließen.
#
# **Endzuordnung:**
# - **mp_1:** Haushalt
#
# **Kurzbegründung:**
# Deutlich erkennbare Morgen- und Abendspitzen mit niedrigem Verbrauch in der Nacht und tagsüber – klassisch für private Haushalte.

# %% [markdown]
# ## Mehrere Zeitreihen

# %% [markdown]
# ### Beispieldaten

# %%
hours = np.arange(0, 24, 0.5)

house = 0.3 + 0.7 * (hours > 17) * (hours < 22)
office = 0.2 + 0.8 * (hours > 8) * (hours < 17)
factory = 1.0 + 0.2 * np.sin(hours)

# ===== PLOT =====

plt.figure(figsize=(10,6))

# house
plt.subplot(3,1,1)
plt.plot(hours, house)
plt.title("mp_1")

# office
plt.subplot(3,1,2)
plt.plot(hours, office)
plt.title("mp_2")

# factory
plt.subplot(3,1,3)
plt.plot(hours, factory)
plt.title("mp_3")

plt.tight_layout()
plt.savefig("multi_energy.png")
plt.close()

# Bild laden
with open("multi_energy.png", "rb") as f:
    multi_energy = base64.b64encode(f.read()).decode("utf-8")

# ===== DICT =====

times = pd.date_range(
    start="2025-01-01 00:00",
    periods=96,
    freq="15min"
)

times = times.strftime("%Y-%m-%d %H:%M").tolist()

multi_energy_dict = {
    "mp_1": {
        "unit": "kWh",
        "data": [
            [t, float(v)]
            for t, v in zip(times, house)
        ]
    },
    "mp_2": {
        "unit": "kWh",
        "data": [
            [t, float(v)]
            for t, v in zip(times, office)
        ]
    },
    "mp_3": {
        "unit": "kWh",
        "data": [
            [t, float(v)]
            for t, v in zip(times, factory)
        ]
    }
}

# %% [markdown]
# ### Analyse mit Plots

# %%
result = analyse_plots(multi_energy)

print(f"prompt_tokens: {result['prompt_tokens']}")
print(f"completion_tokens: {result['completion_tokens']}")
print(f"total_tokens: {result['total_tokens']}")

print(result["answer"])
# Out:
# prompt_tokens: 980
# completion_tokens: 683
# total_tokens: 1663
# **Analyse der Zeitreihen:**
#
# ---
#
# ### Zeitreihe 1 (mp_1)
#
# **1. Verbrauchsmuster:**
# - Grundlast über ca. 0.3, plötzliches Ansteigen gegen 17 Uhr auf 1.0 (Spitzenlast) bis etwa 22 Uhr, dann Rückgang auf Grundlastniveau.
#
# **2. Typische Nutzungszeiten:**
# - Großteil der Energie wird abends zwischen ca. 17 und 22 Uhr verbraucht.
#
# **3. Variabilität & Periodizität:**
# - Konstanter Verbrauch mit deutlicher abendlicher Spitze, täglich wiederholbar (hier nur ein Tag sichtbar).
#
# **4. Klassifikation:**
# - **Haushalt**
#
# **5. Begründung:**
# - Das Muster entspricht typischem Haushaltsverhalten: Grundlast (Kühlschrank, Standby etc.), abends starker Mehrverbrauch (Kochen, Licht, Unterhaltungselektronik).
#
# ---
#
# ### Zeitreihe 2 (mp_2)
#
# **1. Verbrauchsmuster:**
# - Grundlast bei ca. 0.25, sprunghafter Anstieg gegen 8 Uhr auf 1.0, Verbrauch bleibt bis etwa 16 Uhr hoch, dann fällt er wieder auf Grundlast.
#
# **2. Typische Nutzungszeiten:**
# - Hoher Verbrauch zwischen etwa 8 und 16 Uhr (klassische Bürozeiten).
#
# **3. Variabilität & Periodizität:**
# - Starker, scharf abgegrenzter Tagesrhythmus, kaum Schwankungen während Nutzungszeit.
#
# **4. Klassifikation:**
# - **Büro**
#
# **5. Begründung:**
# - Das Muster entspricht typischen Büroöffnungszeiten, praktisch keine Nutzung außerhalb der Arbeitszeiten.
#
# ---
#
# ### Zeitreihe 3 (mp_3)
#
# **1. Verbrauchsmuster:**
# - Kontinuierlich periodische Schwankungen zwischen etwa 0.8 und 1.2; keine klaren Ruhe- oder Spitzenzeiten.
#
# **2. Typische Nutzungszeiten:**
# - Keine klar abgegrenzten Nutzungszeiten, gleichmäßiges Auf und Ab über den Tag verteilt.
#
# **3. Variabilität & Periodizität:**
# - Deutliche und regelmäßige Schwankungen (Wellenmuster), vermutlich maschinenabhängig.
#
# **4. Klassifikation:**
# - **Maschine / Anlage**
#
# **5. Begründung:**
# - Das periodische Muster spricht für eine kontinuierlich laufende technische Anlage oder Maschine, evtl. mit Lastzyklen (z. B. Kühlanlage, Pumpensteuerung o. ä.).
#
# ---
#
# ## Vergleich und Zusammenfassung
#
# - **mp_1 (Haushalt):** Grundlast mit starker abendlicher Spitze, typisch für Haushalte.
# - **mp_2 (Büro):** Regulärer “9-to-5”-Zyklus, passend zum Büroalltag.
# - **mp_3 (Maschine / Anlage):** Stetiges, periodisches Verbrauchsmuster, typisch für technische Geräte oder Maschinen mit automatisierten Zyklen.
#
# **Fazit:**
# Die Zeitreihen lassen sich klar den jeweiligen Nutzungstypen zuordnen und zeigen archetypische Verbrauchsprofile für Haushalt, Büro und Maschine/Anlage.

# %% [markdown]
# ### Analyse mit Arrays

# %%
result = analyse_arrays(multi_energy_dict)

print(f"prompt_tokens: {result['prompt_tokens']}")
print(f"completion_tokens: {result['completion_tokens']}")
print(f"total_tokens: {result['total_tokens']}")

print(result["answer"])
# Out:
# prompt_tokens: 2780
# completion_tokens: 1254
# total_tokens: 4034
# **Analyse der Zeitreihen**
#
# ---
#
# ### **mp_1**
#
# #### 1. **Verbrauchsmuster**
# - **Grundlast:** 0.3 kWh von 00:00 bis 08:30 und von 11:00 bis 11:45.
# - **Spitzenlast:** 1.0 kWh von 08:45 bis 10:45 (jeweils 15-Minuten-Takte).
# - **Tagesmuster:** Klare Phase mit höherem Verbrauch, dann Rückkehr auf Grundlast.
#
# #### 2. **Typische Nutzungszeiten**
# - **Hauptnutzungszeitraum:** 08:45 bis 10:45.
# - **Niedriger Verbrauch:** Nacht, früher Morgen und späte Vormittagsstunden.
#
# #### 3. **Variabilität und periodisches Verhalten**
# - Sehr regelmäßiger Ablauf: langer Block mit niedriger Last, gefolgt von kompaktem Block mit hoher Last, dann wieder niedriger Last.
# - Das Wechseln zwischen niedriger und hoher Last spricht für geplante Nutzung.
#
# #### 4. **Klassifikation**
# - **Vermutung:** Büro
#
# #### 5. **Begründung**
# - Die Spitzen fallen typisch in den Beginn eines Büroarbeits-Tages (ca. 9 bis 11 Uhr).
# - Vorher und nachher nur Grundlast, wie sie bei technischen Geräten/Servern üblich ist.
# - Industrie/Fabrik würde längere hohe Last oder andere typische Muster zeigen; Haushalte hätten typischerweise Verbrauchsspitzen am frühen Morgen, abends oder mittags (Frühstück, Abendessen).
# - Für eine Einzelmaschine zu lang und zu viel Grundlast, aber gut passend für ein Büro mit Arbeitsbeginn am Morgen.
#
# ---
#
# ### **mp_2**
#
# #### 1. **Verbrauchsmuster**
# - **Grundlast:** 0.2 kWh fast die ganze Zeit, außer zwischen 04:15 und 08:15.
# - **Spitzenlast:** 1.0 kWh von 04:15 bis 08:15 (längeres Hoch).
# - **Tagesmuster:** Klar abgrenzbare Hochphase am frühen Morgen.
#
# #### 2. **Typische Nutzungszeiten**
# - **Hauptnutzungszeitraum:** 04:15 bis 08:15.
# - **Niedriger Verbrauch:** Rest des Tages.
#
# #### 3. **Variabilität und periodisches Verhalten**
# - Sehr scharf abgegrenzte, zusammenhängende Hochlastperiode am frühen Morgen.
#
# #### 4. **Klassifikation**
# - **Vermutung:** Maschine / Anlage
#
# #### 5. **Begründung**
# - Das Muster wirkt wie ein automatisierter Einschaltvorgang einer Maschine oder Anlage, die früh morgens für mehrere Stunden genutzt wird und ansonsten auf Standby geschaltet ist.
# - Für Büro oder Haushalt untypisch (Verbrauchsspitzen für Haushalte sind selten so früh und so konzentriert).
# - Industrieanlagen könnten ähnlich aussehen, häufig jedoch mit größeren Lasten oder längeren Hochphasen.
# - Die saubere Trennung und das frühe Einschalten passen auf eine bestimmte Maschine im automatisierten Betrieb (z.B. eine Pumpe, Heizung, Fertigungseinheit).
#
# ---
#
# ### **mp_3**
#
# #### 1. **Verbrauchsmuster**
# - Schwankender Verbrauch um ca. 0.8 bis 1.2 kWh.
# - Leicht periodisches Verhalten, aber keine scharfen Sprünge.
# - Durchgehend relativ hohe Grundlast ohne ausgeprägte Spitzennutzung.
#
# #### 2. **Typische Nutzungszeiten**
# - Keine klar abgegrenzten Nutzungszeiten – Verbrauch oszilliert im Tagesverlauf.
#
# #### 3. **Variabilität und periodisches Verhalten**
# - Weiche Schwankungen, annähernd sinusförmig.
# - Kein starker Wechsel zwischen Grund- und Spitzenlast, sondern relativ gleichmäßiger Verbrauch mit wellenförmiger Modulation.
#
# #### 4. **Klassifikation**
# - **Vermutung:** Industrie / Fabrik
#
# #### 5. **Begründung**
# - Dieses Muster ist typisch für kontinuierlich laufende Maschinen und Anlagen im industriellen Betrieb, bei denen viele Verbraucher permanent aktiv sind.
# - Die Schwankungen deuten auf Zusammenwirken mehrerer Lasten, Schichtbetrieb oder variable Produktion hin.
# - Für Haushalt oder Büro zu hohe Grundlast und zu wenig tageszeitliche Strukturen.
# - Für eine einzelne Maschine zu hohe und zu variabel-glatte Last.
#
# ---
#
# ### **Vergleich der Zeitreihen untereinander**
# - **mp_1:** Deutlich tageszeitliche Struktur (typisch Büro), nur für einen kurzen Zeitraum hohe Last.
# - **mp_2:** Kurzzeitiger, aber klar abgegrenzter Hochlast-Block früh am Morgen, sonst Standby – typisch für gezielte Maschinen-/Anlagen-Nutzung.
# - **mp_3:** Gleichmäßige, modulierte Last, wie sie in Fabriken/Industriebetrieben vorkommt, ohne scharfe Start-/Endzeiten.
#
# ---
#
# ### **Zusammenfassung und Klassifikation**
#
# | Zeitreihe | Kategorie            | Begründung                                                            |
# |-----------|---------------------|----------------------------------------------------------------------|
# | **mp_1**  | Büro                | Tageszeitspezifische Last, passend zu Büroarbeitszeiten               |
# | **mp_2**  | Maschine / Anlage   | Abgegrenzter Hochlast-Block früh, sonst Standby, typisch für Maschine |
# | **mp_3**  | Industrie / Fabrik  | Kontinuierliche Grundlast mit Schwankungen, typisch für Fabrikbetrieb |
#
# **Kurze Zusammenfassung:**
# Die drei Zeitreihen unterscheiden sich deutlich: mp_1 zeigt das typische Muster eines Büros mit Arbeitsbeginn am Morgen. mp_2 weist auf eine Maschine oder Anlage hin, die automatisiert in den Morgenstunden aktiv ist. mp_3 spiegelt das Verbrauchsverhalten einer industriellen Fertigung oder eines größeren kontinuierlich laufenden Betriebs wider.

# %% [markdown]
# # Vergleich

# %%
import matplotlib.pyplot as plt

labels = [
    "One Plot",
    "One Array",
    "Multiple Plots",
    "Multiple Arrays"
]

prompt_tokens = [640, 2231, 980, 2780]
execution_time = [20.1, 8.4, 7.8, 15.3]

colors = ['green', 'blue']

# Prompt Tokens Plot
plt.figure()
plt.bar(labels, prompt_tokens, color=colors)
plt.ylabel("Prompt Tokens")
plt.title("Prompt Tokens Comparison")
plt.show()

# Execution Time Plot
plt.figure()
plt.bar(labels, execution_time, color=colors)
plt.ylabel("Execution Time (seconds)")
plt.title("Execution Time Comparison")
plt.show()
