# %% [markdown]
# # Data Access

# %%
from utils.data_access import(
    get_metering_point_ids_for_user_id,
    load_energy_data
)
import pandas as pd

# %%
metering_point_ids = get_metering_point_ids_for_user_id("user_001")

for m in metering_point_ids:
    print(m)
# Out:
# {'metering_point_id': 'mp_1', 'energy_type': 'consumption'}

# %%
energy_data = load_energy_data("user_001", "mp_001", "2025-01-01", "2025-01-02")

print(energy_data)
# Out:
#    metering_point_id  energy_type           timestamp  value_kwh
# 0             mp_001  consumption 2025-01-01 00:00:00      0.228
# 1             mp_001  consumption 2025-01-01 00:15:00      0.105
# 2             mp_001  consumption 2025-01-01 00:30:00      0.155
# 3             mp_001  consumption 2025-01-01 00:45:00      0.145
# 4             mp_001  consumption 2025-01-01 01:00:00      0.247
# ..               ...          ...                 ...        ...
# 91            mp_001  consumption 2025-01-01 22:45:00      0.341
# 92            mp_001  consumption 2025-01-01 23:00:00      0.342
# 93            mp_001  consumption 2025-01-01 23:15:00      0.244
# 94            mp_001  consumption 2025-01-01 23:30:00      0.154
# 95            mp_001  consumption 2025-01-01 23:45:00      0.204
#
# [96 rows x 4 columns]
