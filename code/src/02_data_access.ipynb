# %% [markdown]
# # Data Access

# %%
from utils.data_access import(
    get_metering_point_ids_for_user_id,
    load_energy_data
)
import pandas as pd

# %%
metering_point_ids = get_metering_point_ids_for_user_id("user")

for m in metering_point_ids:
    print(m)
# Out:
# {'metering_point_id': 'mp_1', 'energy_type': 'consumption'}
# {'metering_point_id': 'mp_2', 'energy_type': 'consumption'}
# {'metering_point_id': 'mp_3', 'energy_type': 'generation'}

# %%
energy_data = load_energy_data("user", "mp_1", "2025-01-01", "2025-01-02")

print(energy_data)
# Out:
#                        kwh
# timestamp
# 2025-01-01 00:00:00  0.228
# 2025-01-01 00:15:00  0.105
# 2025-01-01 00:30:00  0.155
# 2025-01-01 00:45:00  0.145
# 2025-01-01 01:00:00  0.247
# ...                    ...
# 2025-01-01 22:45:00  0.341
# 2025-01-01 23:00:00  0.342
# 2025-01-01 23:15:00  0.244
# 2025-01-01 23:30:00  0.154
# 2025-01-01 23:45:00  0.204
#
# [96 rows x 1 columns]
