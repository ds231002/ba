# %% [markdown]
# # Tools

# %%
from utils.tools import (
    # basic data
    get_participation_factor,
    get_current_energy,
    get_community_consumption,
    get_community_generation,
    get_measured_energy,
    # operations
    get_statistical_value,
    add_timeseries,
    subtract_timeseries,
    multiply_timeseries,
    divide_timeseries,
    min_timeseries,
    max_timeseries,
    # plot
    create_energy_plot,
    save_plot,
    # answer
    generate_answer,
    # diviated data
    calculate_community_potential,
    calculate_community_coverage,
    calculate_weighted_measured_energy,
)

# %%
consumption_1 = get_community_consumption("2025-01-01 00:00", "2025-01-01 00:30")
consumption_2 = get_community_consumption("2025-01-01 00:00", "2025-01-01 00:30")
print(consumption_1)
print(consumption_2)
# Out:
#                         kwh
# timestamp
# 2025-01-01 00:00:00  11.394
# 2025-01-01 00:15:00   5.250
#                         kwh
# timestamp
# 2025-01-01 00:00:00  11.394
# 2025-01-01 00:15:00   5.250

# %%
get_statistical_value("max", consumption_1)
# Out:
# 11.394

# %%
add_timeseries([consumption_1, consumption_2])
# Out:
#                         kwh
# timestamp
# 2025-01-01 00:00:00  22.788
# 2025-01-01 00:15:00  10.500

# %%
subtract_timeseries(minuend=consumption_1, subtrahend=consumption_2)
# Out:
#                      kwh
# timestamp
# 2025-01-01 00:00:00  0.0
# 2025-01-01 00:15:00  0.0

# %%
multiply_timeseries(consumption_1, 2)
# Out:
#                         kwh
# timestamp
# 2025-01-01 00:00:00  22.788
# 2025-01-01 00:15:00  10.500

# %%
divide_timeseries(consumption_1, 2)
# Out:
#                        kwh
# timestamp
# 2025-01-01 00:00:00  5.697
# 2025-01-01 00:15:00  2.625

# %%
max_timeseries([consumption_1, consumption_2])
# Out:
#                         kwh
# timestamp
# 2025-01-01 00:00:00  11.394
# 2025-01-01 00:15:00   5.250

# %%
consumption_3 = get_community_consumption("2025-01-01 00:00", "2025-01-02 00:00")
consumption_4 = get_community_consumption("2025-01-02 00:00", "2025-01-03 00:00")
print(consumption_3)
# Out:
#                         kwh
# timestamp
# 2025-01-01 00:00:00  11.394
# 2025-01-01 00:15:00   5.250
# 2025-01-01 00:30:00   7.750
# 2025-01-01 00:45:00   7.233
# 2025-01-01 01:00:00  12.366
# ...                     ...
# 2025-01-01 22:45:00  17.032
# 2025-01-01 23:00:00  17.090
# 2025-01-01 23:15:00  12.178
# 2025-01-01 23:30:00   7.688
# 2025-01-01 23:45:00  10.213
#
# [96 rows x 1 columns]

# %%
plot = create_energy_plot("titel", ["label_1", "label_2"], [consumption_3, consumption_4])

# %%
save_plot(plot, "plot")
